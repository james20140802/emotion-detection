# %% [markdown]
# ## Processing data
#
# Get data from csv files and process them

# %% [markdown]
# #### Find current path

# %%
import os
current_path = os.path.dirname(os.path.abspath(''))
current_path
# Out:
# '/Users/drchasekim/Documents/emotion-detection'

# %% [markdown]
# ##### Get data directory path

# %%
data_path = os.path.join(current_path, "data/raw")
data_path
# Out:
# '/Users/drchasekim/Documents/emotion-detection/data/raw'

# %% [markdown]
# #### Read data from csv files

# %%
import pandas as pd

tweets_df = pd.read_csv(data_path+"/tweet_emotions.csv")
tweets_df.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %%
text_emotion_df = pd.read_csv(data_path+"/Text_Emotion/train.csv")
text_emotion_df.head()
# Out:
#                                                 text  emotion
# 0  carefully word blog posts amount criticism hea...        0
# 1  cannot remember little mermaid feeling carefre...        1
# 2  not feeling super well turns cold knocked next...        1
# 3            feel honored part group amazing talents        1
# 4  think helping also began feel pretty lonely lo...        0

# %% [markdown]
# ##### Concat dataframes and drop na values

# %%
print(len(tweets_df) + len(text_emotion_df))

text_df = pd.concat([tweets_df.loc[:, "content"], text_emotion_df.loc[:, "text"]], ignore_index=True)

text_df.dropna(inplace=True)

text_df.head()
# Out:
# 294539
# 0    @tiffanylue i know  i was listenin to bad habi...
# 1    Layin n bed with a headache  ughhhh...waitin o...
# 2                  Funeral ceremony...gloomy friday...
# 3                 wants to hang out with friends SOON!
# 4    @dannycastillo We want to trade with someone w...
# dtype: object

# %% [markdown]
# #### Process text data

# %% [markdown]
# import nltk and download necessary data

# %%
import nltk
nltk.__version__

nltk.download("treebank")
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/drchasekim/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %% [markdown]
# ##### Lowercase and delete ppunctuation, url, hashtag or etc...

# %%
import re

text_df = text_df.apply(lambda x: x.lower())
text_df = text_df.apply(lambda x: re.sub(r"(?:\@|#|http?\://|https?\://|www)\S+", "", x))
text_df = text_df.apply(lambda x: re.sub(r'\W*\b\w{1}\b', "", x))
text_df = text_df.apply(lambda x: re.sub('([.,!?()])', r' \1 ', x))
text_df = text_df.apply(lambda x: re.sub(r'\s{2,}', ' ', x))

text_df.head()
# Out:
# 0     know was listenin to bad habit earlier and st...
# 1    layin bed with headache ughhhh . . . waitin on...
# 2          funeral ceremony . . . gloomy friday . . .
# 3               wants to hang out with friends soon !
# 4     we want to trade with someone who has houston...
# dtype: object

# %% [markdown]
# ##### Tokenize text

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
text_df = text_df.apply(lambda x: tokenizer.tokenize(x))

text_df.head()
# Out:
# 0    [know, was, listenin, to, bad, habit, earlier,...
# 1    [layin, bed, with, headache, ughhhh, ., ., ., ...
# 2    [funeral, ceremony, ., ., ., gloomy, friday, ....
# 3       [wants, to, hang, out, with, friends, soon, !]
# 4    [we, want, to, trade, with, someone, who, has,...
# dtype: object

# %%
text_df.to_list()
# Out:
# [['know',
#   'was',
#   'listenin',
#   'to',
#   'bad',
#   'habit',
#   'earlier',
#   'and',
#   'started',
#   'freakin',
#   'at',
#   'his',
#   'part',
#   '=',
#   '['],
#  ['layin',
#   'bed',
#   'with',
#   'headache',
#   'ughhhh',
#   '.',
#   '.',
#   '.',
#   'waitin',
#   'on',
#   'your',
#   'call',
#   '.',
#   '.',
#   '.'],
#  ['funeral', 'ceremony', '.', '.', '.', 'gloomy', 'friday', '.', '.', '.'],
#  ['wants', 'to', 'hang', 'out', 'with', 'friends', 'soon', '!'],
#  ['we',
#   'want',
#   'to',
#   'trade',
#   'with',
#   'someone',
#   'who',
#   'has',
#   'houston',
#   'tickets',
#   ',',
#   'but',
#   'no',
#   'one',
#   'will',
#   '.'],
#  ['re-pinging',
#   'why',
#   'didn',
#   'you',
#   'go',
#   'to',
#   'prom',
#   '?',
#   'bc',
#   'my',
#   'bf',
#   'didn',
#   'like',
#   'my',
#   'friends'],
#  ['should',
#   'be',
#   'sleep',
#   ',',
#   'but',
#   'im',
#   'not',
#   '!',
#   'thinking',
#   'about',
#   'an',
#   'old',
#   'friend',
#   'who',
#   'want',
#   '.',
#   'but',
#   'he',
#   'married',
#   'now',
#   '.',
#   'damn',
#   ',',
#   '&',
#   'amp',
#   ';',
#   'he',
#   'wants',
#   'me',
#   '!',
#   'scandalous',
#   '!'],
#  ['hmmm', '.', 'is', 'down'],
#  ['charlene', 'my', 'love', 'miss', 'you'],
#  ['sorry', 'at', 'least', 'it', 'friday', '?'],
#  ['cant', 'fall', 'asleep'],
#  ['choked', 'on', 'her', 'retainers'],
#  ['ugh',
#   'have',
#   'to',
#   'beat',
#   'this',
#   'stupid',
#   'song',
#   'to',
#   'get',
#   'to',
#   'the',
#   'next',
#   'rude',
#   '!'],
#  ['if',
#   'watch',
#   'the',
#   'hills',
#   'in',
#   'london',
#   'will',
#   'realise',
#   'what',
#   'tourture',
#   'it',
#   'is',
#   'because',
#   'were',
#   'weeks',
#   'and',
#   'weeks',
#   'late',
#   'just',
#   'watch',
#   'itonlinelol'],
#  ['got', 'the', 'news'],
#  ['the', 'storm', 'is', 'here', 'and', 'the', 'electricity', 'is', 'gone'],
#  ['agreed'],
#  ['so',
#   'sleepy',
#   'again',
#   'and',
#   'it',
#   'not',
#   'even',
#   'that',
#   'late',
#   'fail',
#   'once',
#   'again',
#   '.'],
#  ['lady',
#   'gaga',
#   'tweeted',
#   'about',
#   'not',
#   'being',
#   'impressed',
#   'by',
#   'her',
#   'video',
#   'leaking',
#   'just',
#   'so',
#   'you',
#   'know'],
#  ['how',
#   'are',
#   'you',
#   'convinced',
#   'that',
#   'have',
#   'always',
#   'wanted',
#   'you',
#   '?',
#   'what',
#   'signals',
#   'did',
#   'give',
#   'off',
#   '.',
#   '.',
#   '.',
#   'damn',
#   'think',
#   'just',
#   'lost',
#   'another',
#   'friend'],
#  ['oh',
#   'too',
#   'bad',
#   'hope',
#   'it',
#   'gets',
#   'better',
#   "'ve",
#   'been',
#   'having',
#   'sleep',
#   'issues',
#   'lately',
#   'too'],
#  ['wondering',
#   'why',
#   'awake',
#   'at',
#   '7am',
#   ',',
#   'writing',
#   'new',
#   'song',
#   ',',
#   'plotting',
#   'my',
#   'evil',
#   'secret',
#   'plots',
#   'muahahaha',
#   '.',
#   '.',
#   '.',
#   'oh',
#   'damn',
#   'it',
#   ',',
#   'not',
#   'secret',
#   'anymore'],
#  ['no',
#   'topic',
#   'maps',
#   'talks',
#   'at',
#   'the',
#   'balisage',
#   'markup',
#   'conference',
#   '2009',
#   'program',
#   'online',
#   'at',
#   '(',
#   'via'],
#  ['ate',
#   'something',
#   'don',
#   'know',
#   'what',
#   'it',
#   'is',
#   '.',
#   '.',
#   '.',
#   'why',
#   'do',
#   'keep',
#   'telling',
#   'things',
#   'about',
#   'food'],
#  ['so',
#   'tired',
#   'and',
#   'think',
#   'definitely',
#   'going',
#   'to',
#   'get',
#   'an',
#   'ear',
#   'infection',
#   '.',
#   'going',
#   'to',
#   'bed',
#   '&',
#   'quot',
#   ';',
#   'early',
#   '&',
#   'quot',
#   ';',
#   'for',
#   'once',
#   '.'],
#  ['on',
#   'my',
#   'way',
#   'home',
#   'having',
#   'deal',
#   'underage',
#   'girls',
#   'drinking',
#   'gin',
#   'on',
#   'da',
#   'bus',
#   'while',
#   'talking',
#   'bout',
#   'keggers',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'damn',
#   'feel',
#   'old'],
#  ['sorry',
#   'people',
#   'are',
#   'so',
#   'rude',
#   'to',
#   'you',
#   ',',
#   'isaac',
#   ',',
#   'they',
#   'should',
#   'get',
#   'some',
#   'manners',
#   'and',
#   'know',
#   'better',
#   'than',
#   'to',
#   'be',
#   'so',
#   'lewd',
#   '!'],
#  ['damm',
#   'servers',
#   'still',
#   'down',
#   'need',
#   'to',
#   'hit',
#   '80',
#   'before',
#   'all',
#   'the',
#   'koxpers',
#   'pass',
#   'me'],
#  ['fudge',
#   '.',
#   '.',
#   '.',
#   '.',
#   'just',
#   'bs',
#   'that',
#   'whole',
#   'paper',
#   '.',
#   '.',
#   '.',
#   '.',
#   'so',
#   'tired',
#   '.',
#   '.',
#   '.',
#   '.',
#   'ugh',
#   'hate',
#   'school',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'time',
#   'to',
#   'sleep',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['hate', 'cancer', 'hate', 'it', 'hate', 'it', 'hate', 'it', '.'],
#  ['it',
#   'is',
#   'so',
#   'annoying',
#   'when',
#   'she',
#   'starts',
#   'typing',
#   'on',
#   'her',
#   'computer',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'night',
#   '!'],
#  ['cant', 'sleep'],
#  ['missed', 'the', 'bl', 'bus', '!', '!', '!', '!', '!', '!', '!', '!'],
#  ['feels', 'strong', 'contractions', 'but', 'wants', 'to', 'go', 'out', '.'],
#  ['socal', '!', 'stoked', '.', 'or', 'maybe', 'not', '.', '.', 'tomorrow'],
#  ['screw', 'you', 'only', 'have', 'weeks', '.', '.', '.'],
#  ['yeah',
#   'feel',
#   'all',
#   'funny',
#   'cause',
#   'haven',
#   'slept',
#   'enough',
#   'woke',
#   'my',
#   'mum',
#   'up',
#   'cause',
#   'was',
#   'singing',
#   'she',
#   'not',
#   'impressed',
#   'you',
#   '?'],
#  ['need', 'skott', 'right', 'now'],
#  ['has', 'work', 'this', 'afternoon'],
#  ['aw',
#   'you',
#   'would',
#   'not',
#   'unfollow',
#   'me',
#   'would',
#   'you',
#   '?',
#   'then',
#   'would',
#   'cry'],
#  ['mmm',
#   'much',
#   'better',
#   'day',
#   '.',
#   '.',
#   '.',
#   'so',
#   'far',
#   '!',
#   'it',
#   'still',
#   'quite',
#   'early',
#   '.',
#   'last',
#   'day',
#   'of'],
#  ['&',
#   'lt',
#   'your',
#   'gon',
#   'na',
#   'be',
#   'the',
#   'first',
#   'twitter',
#   ';',
#   ')',
#   'cause',
#   'your',
#   'amazing',
#   'lol',
#   '.',
#   'come',
#   'to',
#   'canada',
#   'would',
#   'do',
#   'anything',
#   'to',
#   'see',
#   'you',
#   'perform'],
#  ['just',
#   'picked',
#   'up',
#   'her',
#   'blackberry',
#   'from',
#   'the',
#   'middle',
#   'of',
#   'the',
#   'street',
#   '!',
#   'both',
#   'she',
#   'and',
#   'it',
#   'are',
#   'crushed',
#   '!'],
#  ['why',
#   'do',
#   'have',
#   'the',
#   'feeling',
#   'should',
#   'be',
#   'packing',
#   'and',
#   'hitting',
#   'for',
#   'sfo',
#   'around',
#   'this',
#   'time',
#   'of',
#   'the',
#   'year',
#   'think',
#   'missing',
#   'something',
#   '.',
#   '.',
#   '.'],
#  ['middle',
#   'school',
#   'and',
#   'elem',
#   '.',
#   'high',
#   'schools',
#   'will',
#   'remain',
#   'open',
#   'for',
#   'those',
#   'who',
#   'need',
#   'credits',
#   'to',
#   'graduate',
#   '.',
#   'cali',
#   'is',
#   'broken'],
#  ['bed',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '.',
#   '.',
#   '.',
#   'its',
#   'time',
#   ',',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'hope',
#   'go',
#   'to',
#   'school',
#   'tomorrow',
#   ',',
#   'all',
#   'though',
#   'don',
#   'feel',
#   'very',
#   'well',
#   'right',
#   'now'],
#  ['ahh',
#   '.',
#   '.',
#   '.',
#   '.',
#   'well',
#   'was',
#   'hoping',
#   'that',
#   'could',
#   'learn',
#   'some',
#   'stuff',
#   'on',
#   'the',
#   'way',
#   '.',
#   '.',
#   '.',
#   '.',
#   'why',
#   'not',
#   'you',
#   'and',
#   'work',
#   'on',
#   'separate',
#   'things',
#   'but',
#   'also'],
#  ['having',
#   'problem',
#   'with',
#   'my',
#   'photo',
#   'here',
#   'in',
#   'twitter',
#   'amf',
#   '!',
#   '!',
#   '!',
#   '.',
#   '.',
#   '.',
#   'can',
#   'see',
#   'my',
#   'face',
#   '!'],
#  ['oh',
#   'noooo',
#   '!',
#   'if',
#   'blow',
#   'tire',
#   'you',
#   "'re",
#   'reaaaally',
#   'going',
#   'to',
#   'have',
#   'to',
#   'send',
#   'up',
#   'some',
#   'batman',
#   'smoke',
#   '.'],
#  ['wnna', 'take', 'bath', '!', '!', '!', '!'],
#  ['chocolate',
#   'milk',
#   'is',
#   'so',
#   'much',
#   'better',
#   'through',
#   'straw',
#   'lack',
#   'said',
#   'straw'],
#  ['why', 'am', 'so', 'tired', '?'],
#  ['hey', 'yu', 'lil', 'fucker', 'textd', 'yu'],
#  ['time',
#   'diff',
#   'and',
#   "'ve",
#   'just',
#   'been',
#   'wrapped',
#   'up',
#   'in',
#   'day',
#   'to',
#   'day',
#   'stuff',
#   'so',
#   'havent',
#   'been',
#   'tweeting',
#   '.',
#   'talk',
#   'soon',
#   ',',
#   'must',
#   'sleep',
#   '.',
#   '.',
#   '.',
#   'up',
#   'in',
#   '6hrs'],
#  ['no', 'way', '!', 'damn', 'that', 'sucks', '!', 'are', 'you', 'ok', '?'],
#  ['sucks',
#   'not',
#   'being',
#   'able',
#   'to',
#   'take',
#   'days',
#   'off',
#   'of',
#   'work',
#   'or',
#   'have',
#   'the',
#   'money',
#   'to',
#   'take',
#   'the',
#   'trip',
#   'so',
#   'sad'],
#  ['bed',
#   '.',
#   '.',
#   '.',
#   'sorta',
#   '.',
#   'today',
#   'was',
#   'good',
#   ',',
#   'sara',
#   'has',
#   'strep',
#   'thought',
#   'angelina',
#   'does',
#   'to',
#   'shared',
#   'water',
#   'with',
#   'her',
#   'b4',
#   'they',
#   'told',
#   'me',
#   'will',
#   'prob',
#   'get',
#   'it',
#   'to'],
#  ['the',
#   'recession',
#   '.',
#   'her',
#   'hotel',
#   'are',
#   'restructuring',
#   'how',
#   'the',
#   'accounts',
#   'are',
#   'done',
#   '.',
#   'adds',
#   'bit',
#   'more',
#   'pressure',
#   'in',
#   'the',
#   'short',
#   'term',
#   'but',
#   'we',
#   "'ll",
#   'cope'],
#  ['but', 'got', 'dibs', 'on', 'sulu', '.', '.', '.'],
#  ['aww',
#   'onward',
#   'and',
#   'upwards',
#   'now',
#   ',',
#   'yay',
#   '!',
#   'still',
#   'sad',
#   'to',
#   'leave',
#   'bet',
#   '.'],
#  ['at', 'once', 'haha', '.', 'poor', 'aby', 'still', 'gets', 'sore', '!'],
#  ['diesel',
#   'yaris',
#   '.',
#   '.',
#   '.',
#   '70mpg',
#   'so',
#   'sad',
#   'its',
#   'not',
#   'available',
#   'in',
#   'the',
#   'us',
#   '.',
#   'that',
#   'be',
#   'awesome',
#   '.'],
#  ['want',
#   'to',
#   'buy',
#   'this',
#   'great',
#   'album',
#   'but',
#   'unfortunately',
#   'dont',
#   'hav',
#   'enuff',
#   'funds',
#   'its',
#   '&',
#   'quot',
#   ';',
#   'long',
#   'time',
#   'noisy',
#   '&',
#   'quot',
#   ';'],
#  ['in', 'all', 'honesty', '.', '.', '.', 'pain', 'blech', '.'],
#  ['ok',
#   '.',
#   '.',
#   '.',
#   'the',
#   'passengers',
#   '.',
#   '.',
#   '.',
#   'no',
#   'one',
#   'is',
#   'alive',
#   '.',
#   '.',
#   '.',
#   'they',
#   "'re",
#   'all',
#   'dead',
#   '.',
#   '.',
#   '.',
#   'you',
#   'just',
#   'don',
#   'know',
#   'it',
#   'til',
#   'the',
#   'end',
#   '.',
#   '.',
#   '.',
#   'then',
#   'you',
#   'cry',
#   '.',
#   '.',
#   '.'],
#  ['at', 'home', 'alone', 'with', 'not', 'much', 'to', 'do'],
#  ['ia',
#   'so',
#   'much',
#   'haven',
#   'really',
#   'been',
#   'happy',
#   'with',
#   'any',
#   'of',
#   'cooks',
#   'choices',
#   'for',
#   'singles',
#   '.'],
#  ['fell',
#   'asleep',
#   'on',
#   'the',
#   'beach',
#   'and',
#   'didn',
#   'put',
#   'on',
#   'enough',
#   'sunscreen',
#   'lol'],
#  ['so',
#   'think',
#   'my',
#   'son',
#   'might',
#   'have',
#   'the',
#   'flu',
#   'cause',
#   'def',
#   '.',
#   'just',
#   'cleaned',
#   'up',
#   'stanky',
#   'puke',
#   'mess',
#   'poor',
#   'pumkpin'],
#  ['so',
#   'great',
#   'to',
#   'see',
#   'oin',
#   '&',
#   'amp',
#   ';',
#   'cynthia',
#   '.',
#   'so',
#   'happy',
#   '.',
#   'dinner',
#   'was',
#   'great',
#   ',',
#   'cute',
#   'little',
#   'place',
#   '.',
#   'too',
#   'bad',
#   'oin',
#   'got',
#   'sick',
#   'afterwards',
#   '.'],
#  ['cant', 'give', 'any', 'bday', 'nudges', '.'],
#  ['.',
#   '.',
#   '.',
#   'and',
#   'all',
#   'woman',
#   'who',
#   'transfer',
#   'their',
#   'first',
#   'impressions',
#   '(',
#   'sexual/maternal',
#   ')',
#   'onto',
#   'less',
#   "'threatening",
#   "'",
#   'man',
#   '--',
#   'are',
#   'themselves',
#   'as',
#   'weak',
#   'as',
#   "'him",
#   "'"],
#  ['brothers',
#   'bloom',
#   'won',
#   'be',
#   'opening',
#   'this',
#   'weekend',
#   'in',
#   'el',
#   'paso',
#   "'ll",
#   'just',
#   'buy',
#   'brick',
#   'and',
#   'enjoy',
#   'that',
#   'until',
#   'can',
#   'watch',
#   'brothers',
#   'bloom',
#   '.'],
#  ['says', 'miss', 'plurking', '.'],
#  ['bitten',
#   'to',
#   'blood',
#   'by',
#   'my',
#   'cat',
#   ',',
#   'on',
#   'my',
#   'way',
#   'for',
#   'rabies',
#   'bacterin',
#   '.',
#   'seems',
#   'shots',
#   'for',
#   'months',
#   '.',
#   'never',
#   'wash',
#   'my',
#   'cats',
#   'at',
#   'home',
#   'again',
#   ',',
#   'they',
#   'hate',
#   'water'],
#  ['miss', 'voobys', '!'],
#  ['neither', 'are', 'elp', '!', '!'],
#  ['dude',
#   ',',
#   'that',
#   'is',
#   'my',
#   'favorite',
#   'sandwich',
#   'place',
#   'ever',
#   '.',
#   'ummm',
#   'did',
#   'you',
#   'take',
#   'pictures',
#   '?'],
#  ['is',
#   'sad',
#   'that',
#   'shin',
#   'ae',
#   'got',
#   'married',
#   '.',
#   '.',
#   '.',
#   'and',
#   'it',
#   'wasn',
#   'to',
#   'alex'],
#  ['sure',
#   'you',
#   'will',
#   'tweet',
#   'about',
#   'this',
#   'when',
#   'you',
#   "'re",
#   'back',
#   ',',
#   'but',
#   'news',
#   'is',
#   'abuzz',
#   'about',
#   'tr',
#   'knight',
#   'leaving',
#   '&',
#   'quot',
#   ';',
#   'confirmed',
#   '&',
#   'quot',
#   ';',
#   'today',
#   '.',
#   'muy',
#   'triste',
#   '.'],
#  ['ohh',
#   'thursday',
#   'have',
#   'exams',
#   '.',
#   '.',
#   'all',
#   'day',
#   'what',
#   'about',
#   'wednesday',
#   '?'],
#  ['there',
#   'was',
#   'mix',
#   'up',
#   'with',
#   'my',
#   'dentist',
#   'appt',
#   'this',
#   'afternoon',
#   '.',
#   'so',
#   'they',
#   'rescheduled',
#   'me',
#   'for',
#   'tomorrow',
#   '@',
#   '9am',
#   '.'],
#  ['was',
#   'just',
#   'thinking',
#   'about',
#   'how',
#   'excited',
#   'am',
#   'for',
#   'you',
#   'guys',
#   'to',
#   'move',
#   ',',
#   'but',
#   'then',
#   'realized',
#   'how',
#   'sad',
#   'am',
#   'to',
#   'see',
#   'you',
#   'go',
#   '.'],
#  ['goooood',
#   'mooorning',
#   'people',
#   '.',
#   '.',
#   '.',
#   'sun',
#   'is',
#   'out',
#   '.',
#   '.',
#   'definitly',
#   'spring',
#   'now',
#   ',',
#   'we',
#   'had',
#   'our',
#   'first',
#   'spring',
#   'hail',
#   'storm',
#   ',',
#   'my',
#   'car',
#   'has',
#   'dimples',
#   'now',
#   '.',
#   '.'],
#  ['love',
#   'those',
#   "'it'sakey",
#   "'",
#   'usb',
#   'sticks',
#   '.',
#   'we',
#   'only',
#   'have',
#   'the',
#   '4gb',
#   'in',
#   'australia'],
#  ['fresh',
#   'prince',
#   'and',
#   'sleepy',
#   'sleeps',
#   'my',
#   'nightly',
#   'routine',
#   'got',
#   'ta',
#   'go',
#   'to',
#   'dmv',
#   'early',
#   'tmrw'],
#  ['dammit',
#   '!',
#   'hulu',
#   'desktop',
#   'has',
#   'totally',
#   'screwed',
#   'up',
#   'my',
#   'ability',
#   'to',
#   'talk',
#   'to',
#   'particular',
#   'port',
#   'on',
#   'one',
#   'of',
#   'our',
#   'dev',
#   'servers',
#   '.',
#   'so',
#   'can',
#   'watch',
#   'and',
#   'code'],
#  ['am',
#   'jealous',
#   'of',
#   'your',
#   'mom',
#   'talking',
#   'to',
#   'want',
#   'to',
#   'see',
#   'you',
#   'all',
#   'our',
#   'twittering',
#   'is',
#   'making',
#   'me',
#   'miss',
#   'you'],
#  ['can',
#   'sleep',
#   'keep',
#   'thinking',
#   'about',
#   'the',
#   'puppy',
#   'played',
#   'with',
#   'today'],
#  ['suppposed',
#   'to',
#   'be',
#   'sleep',
#   '.',
#   'but',
#   'got',
#   'some',
#   'much',
#   'to',
#   'do',
#   '.',
#   '&',
#   'amp',
#   'got',
#   'that',
#   'one',
#   'part',
#   'of',
#   'the',
#   'song',
#   'stuck',
#   'in',
#   'my',
#   'head',
#   '&',
#   'quot',
#   ';',
#   'your',
#   'jerk',
#   '(',
#   'iknow',
#   ')',
#   '&',
#   'quot',
#   ';',
#   'blaahh'],
#  ['what', 'going', 'on', 'sweetheart', '?'],
#  ['how',
#   'can',
#   'it',
#   'be',
#   'so',
#   'freaking',
#   'difficult',
#   'to',
#   'get',
#   'system-wide',
#   'spellchecker',
#   '?',
#   'shit',
#   'settle',
#   'for',
#   'an',
#   'office',
#   'suite',
#   'one',
#   '.',
#   'stupid',
#   'unhelpful',
#   'windows'],
#  ['last',
#   'one',
#   'month',
#   'due',
#   'to',
#   'summer',
#   ',',
#   'strawberry',
#   'is',
#   'not',
#   'availble',
#   'in',
#   'the',
#   'chennai',
#   'markets',
#   '!'],
#  ['work', 'at', '6am', '.', 'got', 'ta', 'go', 'to', 'bed', 'soon'],
#  ['correct',
#   'adore',
#   'him',
#   'just',
#   'plucked',
#   'him',
#   'up',
#   'and',
#   'put',
#   'him',
#   'under',
#   'my',
#   'arm',
#   'cuz',
#   'he',
#   'was',
#   'cryin',
#   '.',
#   'all',
#   'better',
#   'now',
#   '!',
#   'hahaha'],
#  ['hiii', 'im', 'on', 'my', 'ipod', 'cant', 'fall', 'asleep'],
#  ['dont', 'wan', 'na', 'work', '11-830', 'tomorrow', 'but', 'get', 'paid'],
#  ['feels',
#   'sad',
#   'coz',
#   'wasnt',
#   'able',
#   'to',
#   'play',
#   'with',
#   'the',
#   'guys',
#   '!',
#   '!',
#   '!'],
#  ['princecharming'],
#  ['@',
#   'cayogial',
#   'wanted',
#   'to',
#   'come',
#   'to',
#   'bz',
#   'this',
#   'summer',
#   ':',
#   '/',
#   'not',
#   'so',
#   'sure',
#   'anymore',
#   'teacher',
#   'life',
#   'in',
#   'the',
#   'summer',
#   'sucks'],
#  ['first',
#   'ever',
#   'dropped',
#   'call',
#   'on',
#   'my',
#   'mobile',
#   '.',
#   'on',
#   'call',
#   'to',
#   'no',
#   'less',
#   '!',
#   '(',
#   'being',
#   'charged',
#   'for',
#   'data',
#   'even',
#   'though',
#   'have',
#   'data',
#   'pack',
#   ')'],
#  ['you', 'win', '.', '.', '.', 'sigh', 'rakeem'],
#  ['oh', 'is', 'that', 'time', 'for', 'real', '?'],
#  ['darn',
#   'these',
#   'allergies',
#   'don',
#   'like',
#   'this',
#   'time',
#   'of',
#   'year',
#   'because',
#   'of',
#   'this',
#   'never',
#   'used',
#   'to',
#   'have',
#   'this',
#   'problem',
#   'either'],
#  ['oh', 'no', 'one', 'minute', 'too', 'late', '!', 'oh', 'well'],
#  ['damn', ',', 'that', 'sucks'],
#  ['wanted',
#   'to',
#   'come',
#   'to',
#   'bz',
#   'this',
#   'summer',
#   ':',
#   '/',
#   'not',
#   'so',
#   'sure',
#   'anymore',
#   'teacher',
#   'life',
#   'in',
#   'the',
#   'summer',
#   'sucks'],
#  ['this',
#   'website',
#   'gave',
#   'me',
#   'virus',
#   '!',
#   'when',
#   'opened',
#   'it',
#   'more',
#   'windows',
#   'kept',
#   'popping',
#   'up'],
#  ['ahh',
#   '!',
#   'big',
#   'scary',
#   'bug',
#   'flying',
#   'around',
#   'my',
#   'room',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['wish',
#   'she',
#   'knew',
#   'what',
#   'she',
#   'puts',
#   'me',
#   'through',
#   '.',
#   '.',
#   'she',
#   'stole',
#   'my',
#   'heart',
#   ',',
#   'never',
#   'gave',
#   'it',
#   'back',
#   '.',
#   '.',
#   'and',
#   'occasionally',
#   'she',
#   'likes',
#   'to',
#   'be',
#   'like',
#   'look',
#   'what',
#   'have',
#   '!'],
#  ['is',
#   'up',
#   'with',
#   'nasty',
#   'cough',
#   'cant',
#   'be',
#   'sick',
#   'have',
#   'huge',
#   'weekend',
#   'ahead',
#   'of',
#   'me'],
#  ['that', 'was', 'stone', 'cold', 'crazy', '.', '.', '.', '.', '?'],
#  ['so', 'tired'],
#  ['shift', 'time', 'bbye', 'biochem', 'waaaaahhhhhh', '!', '!'],
#  ['sure',
#   'some1',
#   'will',
#   'cum',
#   'out',
#   'and',
#   'play',
#   'workin',
#   'through',
#   'til',
#   'midnight',
#   '.'],
#  ['second', 'that', 'wish', 'it', 'rained', 'more', 'where', 'am'],
#  ['early',
#   'happy',
#   'day',
#   'of',
#   'birth',
#   'in',
#   'case',
#   'don',
#   'make',
#   'it',
#   '!',
#   'very',
#   'tired',
#   'from',
#   'therapy',
#   'today',
#   'just',
#   'taking',
#   'my',
#   'medicine',
#   '!',
#   'misshu',
#   '!',
#   'love',
#   'ya',
#   '!'],
#  ['damn',
#   'it',
#   'were',
#   'is',
#   'eric',
#   'or',
#   'anyone',
#   'else',
#   'when',
#   'you',
#   'need',
#   'your',
#   'hair',
#   'to',
#   'be',
#   'played',
#   'with'],
#  ['feel', 'deflated', '.', 'ugh', '.', 'no', 'more', 'dog', '.'],
#  ['allergies', 'suck', 'ducks', 'nuts', '.', '&', 'lt'],
#  ['well',
#   'it',
#   'almost',
#   'was',
#   'good',
#   'day',
#   '.',
#   '.',
#   '.',
#   'guess',
#   'just',
#   'retry',
#   'tomorrow'],
#  ['waraku',
#   'is',
#   'tasteless',
#   'and',
#   'expensive',
#   '!',
#   'portion',
#   'is',
#   'so',
#   'little',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   're',
#   ':',
#   'waraku'],
#  ['sounds',
#   'good',
#   '.',
#   'appreciate',
#   'the',
#   'suggestion',
#   '.',
#   'been',
#   'week',
#   'now',
#   'and',
#   'we',
#   "'re",
#   'still',
#   'offline',
#   'time',
#   'to',
#   'ask',
#   'for',
#   'refund',
#   '.',
#   '.',
#   '.'],
#  ['he',
#   'died',
#   '.',
#   'wait',
#   ',',
#   'what',
#   'about',
#   'magic',
#   'jack',
#   'just',
#   'read',
#   'it',
#   '.'],
#  ['youstinkatrespondingtotexts', '!'],
#  ['wonders',
#   'why',
#   'her',
#   'karma',
#   'points',
#   'turned',
#   'into',
#   '.',
#   '00',
#   '.'],
#  ['need',
#   'to',
#   'pack',
#   'for',
#   'cali',
#   'cali',
#   '!',
#   'can',
#   'not',
#   'waittt',
#   '!',
#   'thinking',
#   'glass',
#   'of',
#   'wine',
#   'is',
#   'in',
#   'order',
#   'to',
#   'celebrate',
#   'my',
#   'weekend',
#   'vaca',
#   '.',
#   'still',
#   'work',
#   '2morrow',
#   ',',
#   'tho',
#   '.'],
#  ['is', 'miserable', 'feel', 'like', 'im', 'gona', 'cry', 'sux', '!'],
#  ['well',
#   'ran',
#   'out',
#   'of',
#   'beer',
#   'so',
#   'left',
#   '.',
#   'not',
#   'sure',
#   'about',
#   'the',
#   'eta',
#   '.',
#   'waiting',
#   'waiting',
#   'waiting',
#   '.',
#   'bleh',
#   'gon',
#   'na',
#   'be',
#   'long',
#   'nite',
#   'methinks',
#   '.'],
#  ['$',
#   'my',
#   'nose',
#   'stud',
#   'fell',
#   'out',
#   'and',
#   'can',
#   'find',
#   'it',
#   'looks',
#   'like',
#   "'ll",
#   'have',
#   'to',
#   'head',
#   'into',
#   'amsterdam',
#   'today',
#   'and',
#   'get',
#   'new',
#   'one'],
#  ['claire',
#   'love',
#   'the',
#   'show',
#   ',',
#   'got',
#   'into',
#   'the',
#   'office',
#   '@',
#   '5am',
#   'and',
#   'no',
#   'radio'],
#  ['pats',
#   'in',
#   'philly',
#   'at',
#   'am',
#   'love',
#   'it',
#   '.',
#   'mmm',
#   'cheesesteak',
#   '.',
#   'miss',
#   'my',
#   'boyfriend',
#   'but',
#   'love',
#   'vacation',
#   '.'],
#  ['*sigh',
#   'going',
#   'to',
#   'bed',
#   'just',
#   'don',
#   'feel',
#   'right',
#   'anymore',
#   '.',
#   '.',
#   '.'],
#  ['what',
#   'focused',
#   'on',
#   'tom',
#   'so',
#   'much',
#   'didn',
#   'see',
#   'my',
#   'beloved',
#   'barack',
#   '!',
#   'oh',
#   'no',
#   'must',
#   'vote',
#   'for',
#   'both',
#   '!',
#   'poor',
#   'president',
#   'only',
#   'has',
#   '626',
#   'votes',
#   '.'],
#  ['epicentre', 'wheelock', 'place', '-', 'tourists', 'only', '.', '.'],
#  ['now',
#   'am',
#   'depressed',
#   'after',
#   'watching',
#   'so',
#   'you',
#   'think',
#   'you',
#   'can',
#   'dance'],
#  ['just',
#   'cross',
#   "'cause",
#   'stuck',
#   'twiddling',
#   'my',
#   'thumbs',
#   'now',
#   ',',
#   'ugh'],
#  ['miss', "16'th"],
#  ['know',
#   '.',
#   'but',
#   'like',
#   'said',
#   'have',
#   'no',
#   'idea',
#   'how',
#   'long',
#   'it',
#   'takes',
#   'for',
#   'them',
#   'to',
#   'investigate',
#   'this',
#   'stuff',
#   '.'],
#  ['cant', 'sleep', ',', 'but', 'im', 'too', 'sore', 'to', 'move'],
#  ['-', 'awe', 'miss', 'my', 'baby'],
#  ['just',
#   'answered',
#   'you-',
#   'never',
#   'learned',
#   'how',
#   'to',
#   'write',
#   'in',
#   'french-',
#   'just',
#   'basic',
#   'stuff-'],
#  ['what',
#   'is',
#   'it',
#   'with',
#   'chocolates',
#   'just',
#   'can',
#   'never',
#   'say',
#   'no'],
#  ['achieving',
#   'new',
#   'appreciation',
#   'on',
#   'how',
#   'xml',
#   'build',
#   'script',
#   'can',
#   'really',
#   'be',
#   'painful',
#   'and',
#   'cumbersome'],
#  ['too', 'awake', 'now', 'ill', 'have', 'nap', 'this', 'afternoon'],
#  ['cant', 'do', 'anything'],
#  ['still', 'needs', 'another', 'hours', 'of', 'sleep'],
#  ['at', 'work'],
#  ['rip', 'leonardo', '.', 'you', 'were', 'great', 'mini', 'fiddler', 'crab'],
#  ['morning', 'tweeple', ',', 'way', 'to', 'early', 'again'],
#  ['last', 'day', 'working', 'for', 'the', 'uni', 'today', ',', 'sad', 'times'],
#  ['thanks',
#   'neemah',
#   'gon',
#   'na',
#   'be',
#   'soooo',
#   'close',
#   'to',
#   'you',
#   'and',
#   'izzy',
#   ',',
#   'yet',
#   'so',
#   'far'],
#  ['my', 'head', 'hurts', 'so', 'bad', 'could', 'scream', '!'],
#  ['just',
#   'go',
#   'up',
#   'and',
#   'im',
#   'so',
#   'tired',
#   'and',
#   'my',
#   'airmatras',
#   'is',
#   'broken',
#   'somewhere',
#   'and',
#   'now',
#   'im',
#   'in',
#   'even',
#   'more',
#   'pain'],
#  ['new',
#   'work',
#   'wellness',
#   'challenge',
#   'not',
#   'going',
#   'well',
#   'committed',
#   'to',
#   'not',
#   'check',
#   'email',
#   'between',
#   '10',
#   'pm',
#   'and',
#   'am',
#   '.',
#   'failed',
#   'on',
#   'first',
#   'day',
#   '.',
#   'twice'],
#  ['new',
#   'blog',
#   'post',
#   ':',
#   '[',
#   'blog',
#   ']',
#   'auto',
#   'insuran',
#   'just',
#   'found',
#   'that',
#   'my',
#   'auto',
#   'insurance',
#   'policy',
#   'had',
#   'been',
#   'expired',
#   'am',
#   'too',
#   'careless',
#   '.',
#   '.',
#   '.',
#   ')',
#   '.',
#   '.',
#   'meanw',
#   '.',
#   '.',
#   '.'],
#  ['where',
#   'are',
#   'all',
#   'ma',
#   'bestfriends',
#   'at',
#   '?',
#   ',',
#   'mia',
#   'or',
#   'wat',
#   '?'],
#  ['oh',
#   'men',
#   'really',
#   'can',
#   'see',
#   'my',
#   "face'mon",
#   'guys',
#   '!',
#   '!',
#   '!'],
#  ['showing',
#   'my',
#   'age',
#   '.',
#   'renewed',
#   'my',
#   'tags',
#   'last',
#   'week',
#   ',',
#   'went',
#   'down',
#   '$',
#   '20',
#   '.',
#   'got',
#   'my',
#   'insurance',
#   'renewal',
#   'email',
#   'today',
#   ',',
#   'went',
#   'down',
#   '$',
#   '100',
#   'don',
#   'wan',
#   'na',
#   'be',
#   'old'],
#  ['my', 'sole', 'supporter', 'is', 'not', 'my', 'sole', 'supporter'],
#  ['don',
#   'you',
#   'hate',
#   'it',
#   'when',
#   'you',
#   'finish',
#   'all',
#   'your',
#   'work',
#   'and',
#   'there',
#   'still',
#   '.',
#   '25',
#   'hours',
#   'left',
#   'of',
#   'work',
#   'time'],
#  ['urgh', 'stop', 'it', 'guys'],
#  ['is',
#   'still',
#   'missing',
#   'her',
#   'husband',
#   'really',
#   'want',
#   'him',
#   'home',
#   '.'],
#  ['miss', 'my', 'puppy'],
#  ['days',
#   'of',
#   'this',
#   'month',
#   'left',
#   ',',
#   'and',
#   'only',
#   'have',
#   '400mb',
#   'left',
#   'on',
#   'my',
#   'onpeak',
#   'downloads',
#   '.'],
#  ['up',
#   'is',
#   'out',
#   'didn',
#   'get',
#   'the',
#   'memo',
#   'it',
#   'looks',
#   'amazing',
#   '.'],
#  ["'ve",
#   'given',
#   'up',
#   'on',
#   'pizza',
#   '-',
#   'kids',
#   'would',
#   'never',
#   'let',
#   'me',
#   'have',
#   'my',
#   'fav',
#   '(',
#   'the',
#   'hot',
#   'ones',
#   ')'],
#  ['up',
#   'reading',
#   'tabloids',
#   'about',
#   'other',
#   'people',
#   'lives',
#   '.',
#   '.',
#   '.',
#   'thinking',
#   'what',
#   'gon',
#   'na',
#   'do',
#   'with',
#   'mine',
#   'when',
#   'my',
#   'baby',
#   'leaves',
#   '?'],
#  ['yearling',
#   'in',
#   'pet',
#   'home',
#   'died',
#   '.',
#   '.',
#   '.',
#   'very',
#   'sad',
#   'for',
#   'their',
#   'whole',
#   'family'],
#  ['fun', 'in', 'the', 'sun', 'hmmm', 'hell', 'no', 'it', 'cold'],
#  ['got',
#   'giant',
#   'splinter',
#   'stuck',
#   'up',
#   'underneath',
#   'my',
#   'finger',
#   'nail',
#   'today',
#   'at',
#   'muppets',
#   '.',
#   '.',
#   '.',
#   'it',
#   'hurt',
#   '.',
#   'but',
#   'got',
#   'to',
#   'go',
#   'to',
#   'first',
#   'aid',
#   'for',
#   'the',
#   'first',
#   'time',
#   '!'],
#  ['we',
#   'hate',
#   'change',
#   ',',
#   'so',
#   'of',
#   'course',
#   '.',
#   'we',
#   "'re",
#   'fans',
#   'for',
#   'life',
#   '.',
#   '&',
#   'lt',
#   'oh',
#   'and',
#   'if',
#   'we',
#   'haven',
#   'met',
#   'rob',
#   'by',
#   'then',
#   'something',
#   'went',
#   'horribly',
#   'wrong',
#   '.'],
#  ['is', 'feeling', 'sad', '.', '.', '.', 'for', 'some', 'reason', '.', '.'],
#  ['well',
#   'fuck-',
#   'this',
#   'new',
#   'pain',
#   'med',
#   'has',
#   'an',
#   'odd',
#   'warning',
#   'that',
#   'actually',
#   'applies',
#   'to',
#   'me',
#   'can',
#   'take',
#   'this',
#   '.',
#   '-chan',
#   'is',
#   'displeased',
#   '.'],
#  ['just',
#   'uploaded',
#   'my',
#   'new',
#   'blog',
#   'painful',
#   'story',
#   'about',
#   'an',
#   '80s',
#   'year',
#   'old',
#   'man',
#   'who',
#   'cried',
#   'because',
#   'he',
#   'wanted',
#   'to',
#   'die',
#   '.',
#   '.',
#   '.',
#   'very',
#   'sad'],
#  ['don', 'think', 'so', 'want', 'details', '.'],
#  ['hi',
#   '.',
#   '.',
#   '.',
#   '!',
#   '!',
#   '!',
#   'who',
#   'is',
#   'mary',
#   'poppins',
#   '?',
#   '?',
#   '?'],
#  ['its',
#   'so',
#   'addicting',
#   ',',
#   'but',
#   'its',
#   'kind',
#   'of',
#   'curse',
#   'to',
#   'do',
#   'them',
#   'at',
#   'night',
#   'time',
#   '.',
#   'everytime',
#   'do',
#   'one',
#   'feel',
#   'like',
#   'making',
#   'music',
#   'afterwards'],
#  ['my', 'last', 'tweet', 'didn', 'send', 'bad', 'phone'],
#  ['omg',
#   'ur',
#   'alive',
#   '!',
#   '!',
#   '!',
#   'lol',
#   '2day',
#   'has',
#   'gone',
#   'sooo',
#   'slow',
#   'going',
#   'insane',
#   'grrr',
#   'you',
#   'doing',
#   'anything',
#   'tonight',
#   '?'],
#  ['have', 'headache', 'going', 'to', 'bed', '.', 'goodnight', '!'],
#  ['was', 'watching', 'parental', 'control'],
#  ['did',
#   'you',
#   'get',
#   'them',
#   'from',
#   'california',
#   'vintage',
#   '?',
#   'ahahah',
#   'they',
#   'have',
#   'the',
#   'best',
#   'dresses',
#   'want',
#   'them',
#   'but',
#   'dont',
#   'have',
#   'ebay'],
#  ['just',
#   'saw',
#   'pics',
#   'from',
#   'this',
#   'past',
#   'thanksgiving',
#   'and',
#   'am',
#   'sad',
#   'because',
#   'grandma',
#   'was',
#   'in',
#   'them',
#   '.'],
#  ['it', 'wont', 'let', 'me'],
#  ['took',
#   'shift',
#   'tomorrow',
#   'don',
#   'really',
#   'feel',
#   'like',
#   'working',
#   'right',
#   'now',
#   '.'],
#  ['but', 'now', 'have', 'no', 'money', 'for', 'phone'],
#  ['spent',
#   'last',
#   'night',
#   'in',
#   '&',
#   'amp',
#   '(',
#   'er',
#   ')',
#   '.',
#   'wife',
#   'tangled',
#   'wheels',
#   'with',
#   'daughter',
#   '&',
#   'amp',
#   ';',
#   'hit',
#   'the',
#   'deck',
#   '.',
#   'dislocation',
#   '&',
#   'amp',
#   ';',
#   'fracture',
#   'resulted',
#   '.'],
#  ['days',
#   'about',
#   'ready',
#   'to',
#   'visit',
#   'torchwood',
#   'and',
#   'see',
#   'if',
#   'they',
#   "'ve",
#   'heard',
#   'anything'],
#  ['where', 'are', 'you', '?', 'in', 'bris', 'can', 'hear', 'any', 'thunder'],
#  ['bec',
#   'vs',
#   'fat',
#   'food',
#   '--',
#   '-',
#   'winner',
#   '=',
#   'fat',
#   'food',
#   'but',
#   'not',
#   'this',
#   'weeknend',
#   ',',
#   'ill',
#   'beat',
#   'it',
#   '!'],
#  ['too',
#   'bad',
#   'the',
#   'red',
#   'devils',
#   '.',
#   '.',
#   'disappointing',
#   'to',
#   'say',
#   'the',
#   'least'],
#  ['had',
#   'dream',
#   'about',
#   'pretty',
#   'pretty',
#   'beach',
#   'and',
#   'there',
#   'was',
#   'no',
#   'beach',
#   'when',
#   'woke',
#   'up'],
#  ['have',
#   '3ware',
#   '9650se',
#   ',',
#   'not',
#   'fast',
#   'enough',
#   'for',
#   '3x',
#   'x25',
#   'ssd',
#   'raid5',
#   '.',
#   '800mhz',
#   'iop',
#   'on',
#   'the',
#   'hpt',
#   '.',
#   'might',
#   'try',
#   'an',
#   'adaptec',
#   '5405',
#   '.',
#   '2ghz',
#   ')',
#   '.'],
#  ['when',
#   'da',
#   'heck',
#   'will',
#   'the',
#   'garage',
#   'man',
#   'get',
#   'here',
#   'ask',
#   'you',
#   '.',
#   '.',
#   'when',
#   '.',
#   '.'],
#  ['ate',
#   'mandy',
#   ',',
#   'please',
#   'forgive',
#   'me',
#   'really',
#   'am',
#   'sorry',
#   'don',
#   'wan',
#   'na',
#   'lose',
#   'my',
#   'bff'],
#  ['umm',
#   'yeah',
#   '.',
#   'that',
#   'probably',
#   'pretty',
#   'good',
#   'note',
#   'to',
#   'self',
#   'because',
#   'eeeeee'],
#  ['why', 'are', 'plane', 'tickets', 'so', 'expensive'],
#  ['(',
#   'umm',
#   'yeah',
#   '.',
#   'that',
#   'probably',
#   'pretty',
#   'good',
#   'note',
#   'to',
#   'self',
#   'because',
#   'eeeeee'],
#  ['needs', 'job', 'badly', '!', '!', '!'],
#  ['daaammmnnnnn', 'do', 'wish', 'was', 'there', '.'],
#  ['went',
#   'to',
#   'di',
#   'bella',
#   'coffee',
#   'roasters',
#   'today',
#   'and',
#   'asked',
#   'for',
#   'job',
#   '.',
#   '.',
#   '.',
#   'the',
#   'person',
#   'needed',
#   'to',
#   'speak',
#   'to',
#   'is',
#   'on',
#   'holiday',
#   '.',
#   '.',
#   '.'],
#  ['played',
#   'up',
#   'until',
#   'the',
#   'latter',
#   'parts',
#   'of',
#   'the',
#   'voodoo',
#   'village',
#   'part',
#   'co-op',
#   'until',
#   'lost',
#   'my',
#   'usual',
#   'partner'],
#  ['nite',
#   '.',
#   'now',
#   'up',
#   'bored',
#   'as',
#   'opposed',
#   'to',
#   'almost',
#   'sleep',
#   'frm'],
#  ['is', 'bad', 'friend'],
#  ['happy',
#   'birthdayyy',
#   '!',
#   'hope',
#   'you',
#   'have',
#   'an',
#   'awesome',
#   'day',
#   '.',
#   'didn',
#   'see',
#   'you',
#   'at',
#   'next',
#   'last',
#   'night',
#   '!'],
#  ['im',
#   'doing',
#   'that',
#   'shit',
#   'right',
#   'now',
#   '.',
#   '.',
#   '.',
#   'im',
#   'on',
#   'vacation',
#   'and',
#   'you',
#   'got',
#   'me',
#   'workin'],
#  ['ill', 'be', 'over', 'in', 'an', 'oir'],
#  ['guess',
#   'its',
#   'no',
#   'go',
#   'girlie',
#   'still',
#   'at',
#   'the',
#   'gym',
#   'and',
#   'work',
#   'at:30am'],
#  ['would',
#   'wish',
#   'the',
#   'severe',
#   'migrains',
#   'would',
#   'stop',
#   '!',
#   '!',
#   '!',
#   'doc',
#   'prescriptions',
#   'arent',
#   'working'],
#  ['missed', 'the', 'game'],
#  ['no',
#   'internet',
#   'last',
#   'night',
#   ';',
#   'er',
#   'was',
#   'brill',
#   ',',
#   'there',
#   'was',
#   'massive',
#   'explosion',
#   'at',
#   'the',
#   'end',
#   'of',
#   'nearby',
#   'gas',
#   'works',
#   'er',
#   'on',
#   'standby'],
#  ['cuz', 'airlines', 'are', 'super', 'lame', '.'],
#  ['-', 'still', 'pity', 'it', 'comes', 'with', 'no', 'lamb', 'though'],
#  ['sorry',
#   'to',
#   'hear',
#   'that',
#   '.',
#   'here',
#   'is',
#   'my',
#   'optimist',
#   ':',
#   'things',
#   'will',
#   'get',
#   'better',
#   '.',
#   'for',
#   'all',
#   'of',
#   'us',
#   '.'],
#  ['is',
#   'done',
#   'painting',
#   'all',
#   'the',
#   'bedroom',
#   'furniture',
#   'still',
#   'have',
#   'to',
#   'do',
#   'the',
#   'table',
#   'but',
#   'it',
#   'will',
#   'wait',
#   'until',
#   'after',
#   'the',
#   'move',
#   '.',
#   'uggh',
#   'moving',
#   'in',
#   'the',
#   'heat'],
#  ['so', 'very', 'tired', '.', '.', '.', 'and', 'have', 'insomnia', '.'],
#  ['hungry',
#   'fool',
#   '.',
#   'ill',
#   'probably',
#   'never',
#   'see',
#   'that',
#   'krispy',
#   'kreme',
#   'again',
#   '.',
#   'had',
#   'to',
#   'enjoy',
#   'it',
#   '.',
#   'they',
#   'closing',
#   'down'],
#  ['airport', '?', 'and', 'you', 'didnt', 'show', 'up', 'tonight', 'homo', '!'],
#  ['hate',
#   'bakersfield',
#   'and',
#   'hate',
#   'the',
#   'ports',
#   ',',
#   'let',
#   'me',
#   'go',
#   'home',
#   'already',
#   'want',
#   'to',
#   'start',
#   'my',
#   'vacation',
#   '.'],
#  ['what', 'about', 'me'],
#  ['looking',
#   'for',
#   'desktop',
#   'twitter',
#   'app',
#   'that',
#   'will',
#   'actually',
#   'let',
#   'you',
#   'access',
#   'urls',
#   ',',
#   'any',
#   'suggestions',
#   'liked',
#   'twittle',
#   'but',
#   'no',
#   'linking'],
#  ['people',
#   'in',
#   'my',
#   'house',
#   'do',
#   'not',
#   'know',
#   'how',
#   'to',
#   'close',
#   'doors'],
#  ['why',
#   'am',
#   'completing',
#   'facebook',
#   'quizzes',
#   'at',
#   'this',
#   'time',
#   'of',
#   'the',
#   'morning',
#   '.',
#   '.',
#   '.',
#   'especially',
#   'friday',
#   'morning'],
#  ['out', 'with', '&', 'amp', 'am', 'soooo', 'hungry'],
#  ['don',
#   'like',
#   'the',
#   'possibility',
#   'of',
#   'the',
#   'left',
#   'side',
#   'of',
#   'my',
#   'brain',
#   'hurting',
#   'because',
#   'of',
#   'the',
#   'thing',
#   'called',
#   'vp',
#   'shunt',
#   'and',
#   'possible',
#   'death'],
#  ['had', 'to', 'cancel', 'wow', 'for', 'now'],
#  ['wants',
#   'to',
#   'make',
#   'music',
#   'profile',
#   'but',
#   'don',
#   'have',
#   'money',
#   'don',
#   'know',
#   'how',
#   'to',
#   'write',
#   'music',
#   'don',
#   'know',
#   'how',
#   'to',
#   'play',
#   'an',
#   'instrument',
#   'and',
#   'no',
#   'studio'],
#  ['but',
#   'yeah',
#   'sad',
#   'about',
#   'my',
#   '&',
#   'quot',
#   ';',
#   'ravenclaw',
#   '&',
#   'quot',
#   ';',
#   'account',
#   'love',
#   'that',
#   'account',
#   'to',
#   'bits',
#   '.'],
#  ['it:15',
#   'am',
#   ',',
#   'and',
#   'hear',
#   'helicopter',
#   'flying',
#   'over',
#   'my',
#   'house',
#   '.',
#   'that',
#   'kind',
#   'of',
#   'weird',
#   '.',
#   'in',
#   'other',
#   'news',
#   ',',
#   'my',
#   'headache',
#   'is',
#   'back',
#   '.',
#   'booooo',
#   '.'],
#  ['oh', 'no', 'am', 'always', 'here', ';', ')', '&', 'lt'],
#  ['back',
#   'from',
#   'school',
#   '.',
#   'ms',
#   'suhana',
#   'last',
#   'day',
#   'as',
#   'our',
#   'ft',
#   'ocu',
#   'was',
#   'okay',
#   'playing',
#   'altnoy',
#   'over',
#   'and',
#   'over',
#   'again',
#   '.'],
#  ['@',
#   'poll',
#   ':',
#   'was',
#   'trying',
#   'to',
#   'get',
#   'it',
#   'to',
#   'work',
#   'in',
#   'powerpoint',
#   'to',
#   'no',
#   'avail',
#   '.'],
#  ['took',
#   'math',
#   'test',
#   'today',
#   '.',
#   'the',
#   'day',
#   'before',
#   'the',
#   'test',
#   ',',
#   'the',
#   'teacher',
#   'says',
#   'bring',
#   'your',
#   'calculator',
#   '.',
#   'luke',
#   'was',
#   'confident',
#   '.',
#   'teacher',
#   'decided',
#   'no',
#   'calcs',
#   '.'],
#  ['omg',
#   ',',
#   'the',
#   'concert',
#   'was',
#   'awesome',
#   ',',
#   'madrigals',
#   'gave',
#   'me',
#   'chills',
#   'on',
#   'almost',
#   'every',
#   'piece',
#   '.',
#   '.',
#   '.',
#   'brooks',
#   'also',
#   'called',
#   'up',
#   'alumni',
#   ',',
#   'but',
#   'didnt',
#   'get',
#   'to',
#   'go'],
#  ['yeah',
#   ',',
#   'it',
#   'terrible',
#   'cockatoos',
#   'are',
#   'the',
#   'hardest',
#   'to',
#   'live',
#   'with',
#   ',',
#   'so',
#   'emotional',
#   '.',
#   'good',
#   'thing',
#   'he',
#   'found',
#   'you',
#   ',',
#   'though',
#   '!',
#   '!'],
#  ['up', 'late', 'with', 'nothin', 'do', '.', '.', '.', '.', '.'],
#  ['think',
#   'the',
#   'vog',
#   'is',
#   'making',
#   'me',
#   'sicker',
#   'than',
#   'think',
#   '.',
#   'feeling',
#   'slightly',
#   'achy'],
#  ['was',
#   'watching',
#   'harpers',
#   'island',
#   ',',
#   'lol',
#   '.',
#   '.',
#   '.',
#   'there',
#   'was',
#   'no',
#   'vodka',
#   'involved'],
#  ['am',
#   'doing',
#   'homework',
#   'it',
#   'sux',
#   'big',
#   'time',
#   'maths',
#   'is',
#   'the',
#   'worst',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['would',
#   'have',
#   'been',
#   'better',
#   ',',
#   'imo',
#   ',',
#   'if',
#   'it',
#   'let',
#   'you',
#   'play',
#   'through',
#   'all',
#   'songs',
#   'provided',
#   'just',
#   'start',
#   'to',
#   '&',
#   'quot',
#   ';',
#   'get',
#   'it',
#   '&',
#   'quot',
#   ';',
#   'and',
#   'it',
#   'blacks',
#   'out',
#   '.'],
#  ['it', 'never', 'started', '.', '.', '.'],
#  ['sometimes',
#   'wish',
#   'things',
#   'could',
#   'go',
#   'back',
#   'to',
#   'the',
#   'way',
#   'they',
#   'were',
#   'the',
#   'beginning',
#   'of',
#   'last',
#   'summer'],
#  ['downloaded',
#   'the',
#   'new',
#   'twitterfon',
#   'update',
#   'thinking',
#   'they',
#   'were',
#   'fixing',
#   'the',
#   'typing',
#   'problem',
#   'for',
#   'new',
#   'tweets',
#   ',',
#   'but',
#   'no',
#   ',',
#   'they',
#   'didn'],
#  ['trudy',
#   'off',
#   'burnet',
#   '.',
#   '.',
#   '.',
#   'the',
#   'one',
#   'up',
#   'north',
#   'that',
#   'no',
#   'one',
#   'goes',
#   'to'],
#  ['feel',
#   'the',
#   'same',
#   'way',
#   ',',
#   'but',
#   'guess',
#   'no',
#   'matter',
#   'where',
#   'you',
#   'are',
#   'there',
#   'will',
#   'always',
#   'be',
#   'memes',
#   '.'],
#  ['can',
#   'do',
#   '30',
#   'minutes',
#   'of',
#   'treadmill',
#   'but',
#   'done',
#   '30',
#   'minutes',
#   'for',
#   'today',
#   'already',
#   ',',
#   'gon',
#   'na',
#   'do',
#   '20',
#   'minutes',
#   'more'],
#  ['sooooooooooooo', 'confused'],
#  ['with',
#   'friends',
#   'like',
#   'vaiko',
#   ',',
#   'nedumaran',
#   ',',
#   'ltte',
#   'didn',
#   'need',
#   'enemies',
#   '.',
#   'wrong',
#   'advice',
#   'at',
#   'wrong',
#   'time',
#   'led',
#   'to',
#   'numerous',
#   'deaths',
#   '&',
#   'amp',
#   'lost',
#   'cause',
#   'as',
#   'well'],
#  ['work', 'day', 'of', ','],
#  ['chillin',
#   'with',
#   'the',
#   'roomies',
#   '.',
#   'can',
#   'wait',
#   'for',
#   'the',
#   'zombie',
#   'clwn',
#   'cr',
#   '.',
#   'its',
#   'gon',
#   'na',
#   'be',
#   'weeks'],
#  ['looove',
#   'guitars',
#   ',',
#   'and',
#   'playing',
#   'them',
#   'think',
#   'they',
#   'sound',
#   'magnificent',
#   '.',
#   'if',
#   'only',
#   'was',
#   'better',
#   '.',
#   '.',
#   '.',
#   'if',
#   'only'],
#  ['no',
#   'refunds',
#   'but',
#   'they',
#   'do',
#   'retrieve',
#   'accounts',
#   ',',
#   'takes',
#   'like',
#   'week',
#   '.',
#   'just',
#   'hoping',
#   'the',
#   'thief',
#   'doesn',
#   'use',
#   'hacks',
#   'or',
#   'then',
#   'it',
#   'permaban'],
#  ['no', 'im', 'not', 'cries', 'lol'],
#  ['cute',
#   'malay',
#   'girl',
#   'came',
#   'to',
#   'seemy',
#   'room',
#   'for',
#   'rent',
#   '-',
#   'sadly',
#   'think',
#   'it',
#   'was',
#   'for',
#   'her',
#   'guyfreind',
#   'bit',
#   'misleading',
#   'and',
#   'disappointing',
#   'lol'],
#  ['epicentre',
#   'wheelock',
#   'place',
#   ',',
#   '250',
#   'units',
#   '&',
#   'amp',
#   ';',
#   'for',
#   'tourists',
#   'only',
#   '.',
#   'starting',
#   'today'],
#  ['hate',
#   'the',
#   'new',
#   'mt',
#   'dew',
#   'commercial',
#   '.',
#   '.',
#   'the',
#   'one',
#   'with',
#   'giant',
#   'mosquito',
#   '.',
#   '.',
#   'it',
#   'scares',
#   'me',
#   'and',
#   'grosses',
#   'me',
#   'out',
#   'all',
#   'at',
#   'the',
#   'same',
#   'time',
#   '.'],
#  ['come',
#   'on',
#   'knight',
#   '.',
#   '.',
#   '.',
#   'it',
#   'been',
#   'well',
#   'over',
#   'hours'],
#  ['not',
#   'super',
#   'keen',
#   'on',
#   'the',
#   'drive',
#   'home',
#   'through',
#   'the',
#   'rain',
#   '.',
#   '.',
#   'additional',
#   'concentration',
#   'required',
#   'that',
#   'don',
#   'really',
#   'wan',
#   'na',
#   'deal',
#   'with'],
#  ['aw', 'can', 'let', 'me', 'in', 'on', 'the', 'secret', '!'],
#  ['im',
#   'sorry',
#   'don',
#   'think',
#   'stick',
#   'out',
#   ',',
#   'at',
#   'least',
#   'compared',
#   'to',
#   'what',
#   'used',
#   'to',
#   'look',
#   'like',
#   '.'],
#  ['no',
#   'transport',
#   'for',
#   'church',
#   'wont',
#   'be',
#   'making',
#   'it',
#   ',',
#   'im',
#   'crushed',
#   '.',
#   'oh',
#   'well',
#   ',',
#   'more',
#   'time',
#   'for',
#   'assignments',
#   'suppose',
#   '.',
#   'my',
#   'throat',
#   'really',
#   'hurts',
#   '.',
#   '.',
#   '.'],
#  ['hate',
#   'when',
#   'see',
#   'pregnant',
#   'women',
#   'smokinggg',
#   '!',
#   '!',
#   '!',
#   '!',
#   'its',
#   'sooo',
#   'irresponsible',
#   'selfish',
#   '!',
#   'its',
#   'saaad',
#   '.',
#   'ultimately',
#   ',',
#   'the',
#   'baby',
#   'is',
#   'the',
#   'one',
#   'who',
#   'suffers',
#   '.'],
#  ['lies',
#   '.',
#   '.',
#   '.',
#   'lies',
#   '.',
#   '.',
#   '.',
#   'lies',
#   '.',
#   '.',
#   '.',
#   '.',
#   'you',
#   'just',
#   'cant',
#   'avoid',
#   'to',
#   'lie',
#   'about',
#   'practically',
#   '.',
#   '.',
#   '.',
#   'everything',
#   '!'],
#  ['twittascope',
#   'is',
#   'not',
#   'rocking',
#   'my',
#   'socks',
#   '-',
#   'go',
#   'away',
#   'already',
#   '!',
#   '!'],
#  ['driving',
#   'back',
#   'home',
#   'because',
#   'forgot',
#   'the',
#   'piece',
#   'of',
#   'cake',
#   'for'],
#  ['so',
#   'tried',
#   'jumping',
#   'without',
#   'the',
#   'trampoline',
#   'and',
#   'its',
#   'like',
#   'thud*',
#   'thud*',
#   'shouldn',
#   'have',
#   'eaten',
#   'that',
#   'cookie',
#   '.'],
#  ['everytime',
#   'send',
#   'an',
#   'email',
#   'to',
#   'my',
#   'coach',
#   'feel',
#   'need',
#   'to',
#   'practice',
#   '.',
#   'shitty',
#   'balls',
#   '.',
#   'lol'],
#  ['it',
#   'pissing',
#   'me',
#   'off',
#   'and',
#   'not',
#   'letting',
#   'me',
#   'follow',
#   'ericka'],
#  ['is',
#   'going',
#   'to',
#   'sleep',
#   'not',
#   'peaceful',
#   'wanted',
#   'to',
#   'hear',
#   'him',
#   'say',
#   'good',
#   'night',
#   'but',
#   'that',
#   'didn',
#   'happen',
#   'good',
#   'night',
#   'everyone',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['my',
#   'mums',
#   'trying',
#   'to',
#   'make',
#   'me',
#   'feel',
#   'ebtter',
#   'about',
#   'stopping',
#   'voting',
#   'adn',
#   'not',
#   'winning',
#   'shortstack',
#   'almost',
#   'cried',
#   '.'],
#  ['was',
#   'so',
#   'close',
#   'to',
#   'the',
#   'tacos',
#   '.',
#   '.',
#   '.',
#   'one',
#   'spot',
#   'too',
#   'late'],
#  ['umm',
#   'how',
#   'bout',
#   'em',
#   '?',
#   '.',
#   '.',
#   'aint',
#   'get',
#   'see',
#   'da',
#   'game',
#   'but',
#   'see',
#   'dey',
#   'survived',
#   'anotha',
#   'game',
#   'of',
#   'da',
#   'series',
#   'due',
#   'to',
#   'notin',
#   'but',
#   'lebron',
#   'im',
#   'guessin'],
#  ['is', 'thinking', 'so', 'much', 'and', 'at', 'work'],
#  ['have',
#   'forgot',
#   'the',
#   'live',
#   'with',
#   'the',
#   'jonas',
#   'brothers',
#   'on',
#   'facebook'],
#  ['haven', 'seen', 'muffin', 'in', 'two', 'whole', 'days', '!'],
#  ["'ll",
#   "miss'all",
#   'back',
#   '.',
#   '.',
#   '.',
#   'give',
#   'my',
#   'regards',
#   '.',
#   '.',
#   '.'],
#  ['my', 'gap', 'year', 'is', 'going', 'so', 'quick'],
#  ['have',
#   'to',
#   'admit',
#   'bit',
#   'bummed',
#   'out',
#   'that',
#   'wasn',
#   'with',
#   'my',
#   'friends',
#   'walking',
#   'today',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['girl',
#   'blunt',
#   'is',
#   'soooooooo',
#   'in',
#   'my',
#   'thoughts',
#   'right',
#   'now',
#   'had',
#   'an',
#   'absolutly',
#   'great',
#   'day',
#   'with',
#   'few',
#   'stressors',
#   '.',
#   '.',
#   '.',
#   'come',
#   'home'],
#  ['my', 'twitter', 'has', 'been', 'hacked', 'again'],
#  ['just',
#   'found',
#   'mj',
#   'mouse',
#   'flats',
#   'at',
#   'djs',
#   '.',
#   'of',
#   'course',
#   'there',
#   'are',
#   'none',
#   'left',
#   'in',
#   'my',
#   'size'],
#  ['wont', 'have', 'time', 'to', 'buy', 'and', 'need', 'new', 'binder', 'pa'],
#  ['hahaha', 'well', 'its', 'try', 'its', 'so', 'ugly'],
#  ['25-man', 'ulduar', 'is', 'hard', '.', '.', '.'],
#  ['don',
#   'even',
#   'want',
#   'to',
#   'know',
#   'why',
#   'you',
#   'know',
#   'about',
#   'vhemt',
#   ',',
#   'but',
#   'don',
#   'go',
#   '-',
#   'we',
#   'miss',
#   'you'],
#  ['that',
#   'awesome',
#   '!',
#   'we',
#   'have',
#   'that',
#   'this',
#   'weekend',
#   'too',
#   'but',
#   'can',
#   'go',
#   'because',
#   'moving',
#   'this',
#   'sat',
#   'should',
#   'be',
#   'lot',
#   'of',
#   'fun',
#   'though'],
#  ['night',
#   'night',
#   'twitter',
#   'world',
#   '.',
#   '[',
#   'still',
#   'cant',
#   'believe',
#   'the',
#   'thomas',
#   'thing',
#   'tomorrow',
#   'gunna',
#   'be',
#   'fun/sad',
#   ']'],
#  ['this', 'is', 'happening', 'to', 'me', 'too'],
#  ['oh', 'no', '.', '*hugs*'],
#  ['bored',
#   'now',
#   'because',
#   'was',
#   'talking',
#   'to',
#   'someone',
#   'but',
#   'now',
#   'they',
#   "'re",
#   'busy',
#   'with',
#   'something',
#   'else',
#   'just',
#   'kinda',
#   'bummer',
#   ',',
#   'idk'],
#  ['knoww', 'things', 'won', 'be', 'the', 'samee', '&', 'lt'],
#  ['omg-ness',
#   'it',
#   '11:18',
#   'pm',
#   'and',
#   'need',
#   'to',
#   'beup',
#   'early',
#   'to',
#   'set',
#   'up',
#   'my',
#   'garage',
#   'sale',
#   'it',
#   'starts',
#   '8am',
#   ',',
#   'wish',
#   'said',
#   '9am',
#   'beat',
#   '.'],
#  ['kno',
#   'doooo',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'yall',
#   'partyin',
#   'with',
#   'out',
#   'me'],
#  ['okay',
#   ',',
#   'so',
#   'twitter',
#   'suddenly',
#   'changed',
#   ',',
#   'how',
#   'do',
#   'respond',
#   'to',
#   'messages',
#   'now'],
#  ['ugh',
#   '.',
#   '.',
#   'my',
#   'dad',
#   'just',
#   'told',
#   'me',
#   'to',
#   'read',
#   'an',
#   'article',
#   'about',
#   'kavya',
#   'shivashankar',
#   'the',
#   'spellin',
#   'bee',
#   'girl',
#   '.',
#   '.',
#   'and',
#   'be',
#   'more',
#   'like',
#   'her',
#   '.'],
#  ['decided',
#   'that',
#   'no',
#   'matter',
#   'how',
#   'good',
#   'my',
#   'hair',
#   'looks',
#   'curly',
#   'it',
#   'doesn',
#   'justify',
#   'the',
#   'burn',
#   'get',
#   'from',
#   'the',
#   'curler',
#   '!',
#   'my',
#   'hands',
#   'covered',
#   'suck',
#   'at',
#   'it',
#   '!'],
#  ['going',
#   'to',
#   'sleep',
#   '.',
#   'gon',
#   'na',
#   'fall',
#   'asleep',
#   'playing',
#   'apps',
#   'again',
#   '.',
#   'tmrw',
#   'is',
#   'going',
#   'to',
#   'suck'],
#  ['yea', 'got', 'ta', 'be', 'up', 'at:30'],
#  ['hate',
#   'when',
#   'my',
#   'bf',
#   'beats',
#   'da',
#   'dogs',
#   '.',
#   'but',
#   'guess',
#   'that',
#   'the',
#   'only',
#   'way',
#   'to',
#   'teach',
#   'these',
#   'pitts',
#   '.'],
#  ['sprained',
#   'my',
#   'ankle',
#   'like',
#   'really',
#   'badly',
#   'and',
#   'tore',
#   'some',
#   'stuffs',
#   '.',
#   'it',
#   'hurts',
#   '!',
#   'and',
#   'its',
#   'my',
#   'birthday',
#   'weekend'],
#  ['can',
#   'believe',
#   'the',
#   'metal',
#   'gear',
#   'solid',
#   'song',
#   'was',
#   'stolen',
#   'so',
#   'disappointed'],
#  ['think',
#   'may',
#   'have',
#   'broke',
#   'toe',
#   'at',
#   'the',
#   'bar',
#   'tonight',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'thanks',
#   'drunk',
#   'girl',
#   'for',
#   'steppin',
#   'all',
#   'over',
#   'me',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['not',
#   'one',
#   'sale',
#   'done',
#   'today',
#   'at',
#   'work',
#   '.',
#   'explored',
#   'balconies',
#   'in',
#   'the',
#   'big',
#   'theater',
#   'coworkers',
#   'fun',
#   'day',
#   ',',
#   'but',
#   'void',
#   'of',
#   'chili',
#   'fries',
#   'and',
#   'tips'],
#  ['wish',
#   'had',
#   'left',
#   'dead',
#   '.',
#   'but',
#   'first',
#   'need',
#   'something',
#   'to',
#   'play',
#   'it',
#   'on',
#   '.',
#   '.',
#   '.'],
#  ['me', 'too'],
#  ['that', 'story', 'reminds', 'of', 'living', 'in', 'portugal'],
#  ['youre',
#   'diabetic',
#   '?',
#   'so',
#   'is',
#   'my',
#   'dad',
#   '.',
#   '&',
#   'amp',
#   'might',
#   'be',
#   'too',
#   ',',
#   'not',
#   'sure',
#   '.',
#   'are',
#   'you',
#   'still',
#   'allowed',
#   'to',
#   'eat',
#   'sugar',
#   'throughout',
#   'the',
#   'day',
#   '?'],
#  ['spilled',
#   'my',
#   'beer',
#   'all',
#   'over',
#   'my',
#   'leg',
#   '.',
#   'wasted',
#   'half',
#   'my',
#   'beer',
#   '.',
#   'home',
#   'now',
#   'met',
#   'cute',
#   'girl',
#   '.',
#   'good',
#   'conversation',
#   '.'],
#  ['my', 'roommate', 'loves', 'to', 'ignore', 'me'],
#  ["'ll",
#   'make',
#   'him',
#   'nachos',
#   'tomorrow',
#   '.',
#   'better',
#   'than',
#   'if',
#   'he',
#   'would',
#   'have',
#   'made',
#   'them',
#   'himself',
#   '.'],
#  ['yeahhh', '.', '&', 'amp', ';', 'dont', 'judge', 'my', 'pillow'],
#  ['scary',
#   'lightning',
#   'and',
#   'thunder',
#   'glad',
#   'it',
#   'over',
#   'now',
#   '.',
#   'going',
#   'to',
#   'sleep',
#   'hope',
#   'not',
#   'late',
#   'to',
#   'school',
#   'tomorow',
#   'again',
#   '.',
#   'haha'],
#  ['my', 'teeth', 'and', 'head', 'hurts'],
#  ['hate',
#   'rob',
#   'zombie',
#   'movies',
#   '.',
#   '&',
#   'amp',
#   ';',
#   'the',
#   'smell',
#   'of',
#   'weed',
#   '.',
#   'vommmm',
#   '.'],
#  ['maths',
#   'and',
#   'science',
#   'were',
#   'the',
#   'strongest',
#   'for',
#   'me',
#   'think',
#   '.',
#   '.',
#   'dunno',
#   'bout',
#   'geography',
#   ',',
#   'only',
#   'did',
#   'like',
#   'day',
#   'of',
#   'study',
#   'for',
#   'year',
#   'of',
#   'work',
#   '!'],
#  ['waiting', 'in', 'line', '@', 'tryst'],
#  ['hope',
#   'get',
#   'job',
#   'cuz',
#   'we',
#   'need',
#   'an',
#   'apartment',
#   'drunk',
#   '&',
#   'amp',
#   ';',
#   'miss',
#   'my',
#   'lil',
#   'punkin',
#   'tehe',
#   '!',
#   '!',
#   '!'],
#  ['just',
#   'got',
#   'home',
#   '!',
#   'not',
#   'wanting',
#   'to',
#   'read',
#   'the',
#   'last',
#   'chaper',
#   'of',
#   'breaking',
#   'dawn',
#   'cause',
#   'dont',
#   'want',
#   'it',
#   'to',
#   'beover'],
#  ['need', 'to', 'be', 'held', '.', '.', '.', 'gnite', '.'],
#  ['hanging',
#   'out',
#   'with',
#   'sam',
#   ',',
#   'billy',
#   ',',
#   'and',
#   'veronica',
#   '.',
#   'not',
#   'going',
#   'to',
#   'school',
#   'tomorrow',
#   'to',
#   'take',
#   'sam',
#   'to',
#   'body',
#   'shops',
#   '.',
#   'dang',
#   'car',
#   'accidents'],
#  ['no', 'more', 'arrested', 'development', 'am', 'sad', '.'],
#  ['wicked',
#   ',',
#   'what',
#   'time',
#   'you',
#   'leaving',
#   '?',
#   'how',
#   'come',
#   'you',
#   'cant',
#   'stay',
#   'the',
#   'night'],
#  ['omg',
#   'keep',
#   'losing',
#   'followers',
#   'this',
#   'is',
#   'so',
#   'sad',
#   'want',
#   '90',
#   'one',
#   'day',
#   '.',
#   '.',
#   '.',
#   '.',
#   'thats',
#   'my',
#   'goal'],
#  ['feel', 'so', 'deflated', '.', 'no', 'more', 'doggy', '.'],
#  ['wan', 'na', 'see', 'her', 'hair', 'hows', 'everyone', '?'],
#  ['just',
#   'had',
#   'to',
#   'empty',
#   'my',
#   'trash',
#   'on',
#   'the',
#   'mac',
#   '.',
#   'that',
#   'was',
#   'one',
#   'of',
#   'the',
#   'most',
#   'difficult',
#   'things',
#   'have',
#   'ever',
#   'done',
#   'in',
#   'my',
#   'life',
#   ',',
#   '000',
#   'pictures',
#   'are',
#   'gone',
#   '.'],
#  ['im',
#   'contacting',
#   'paws',
#   'philippines',
#   'so',
#   'can',
#   'find',
#   '&',
#   'quot',
#   ';',
#   'tiger',
#   '&',
#   'quot',
#   'new',
#   'owner',
#   '.',
#   'im',
#   'so',
#   'sad',
#   'love',
#   'my',
#   'dog',
#   'soo',
#   'much'],
#  ['just',
#   'got',
#   'home',
#   '!',
#   'not',
#   'wanting',
#   'to',
#   'read',
#   'the',
#   'last',
#   'chaper',
#   'of',
#   'breaking',
#   'dawn',
#   'cause',
#   'dont',
#   'want',
#   'it',
#   'to',
#   'be',
#   'over'],
#  ['aww',
#   '.',
#   '.',
#   '.',
#   'pray',
#   'for',
#   'the',
#   'arroyo',
#   'family',
#   'everyone',
#   '!'],
#  ['there',
#   'manual',
#   'process',
#   '.',
#   '.',
#   '.',
#   'but',
#   'it',
#   'taking',
#   '4ever',
#   'on',
#   'my',
#   'outlook',
#   'database',
#   '.',
#   '.',
#   '.',
#   'pffff',
#   '.',
#   'crappy',
#   'msft',
#   'product'],
#  ['fuuudge', '.', 'movie', 'store', 'is', 'closed'],
#  ['alo', 'is', 'so', 'sad', 'and', 'quiet', 'and', 'empty', 'tonight'],
# ...
#   'cause',
#   'posted',
#   'picture',
#   'of',
#   'baby'],
#  ['is', 'still', 'sick', 'sigh'],
#  ['oh', 'poor', 'beths', 'friend', 'not', 'naughty', 'just', 'unperfect', '.'],
#  ['josh',
#   'just',
#   'called',
#   'me',
#   'big',
#   'bucket',
#   'of',
#   'ugly',
#   'wish',
#   'me',
#   'luck',
#   'for',
#   'my',
#   'audition',
#   'tweets',
#   '!'],
#  ['feel', 'really', 'weird'],
#  ['trying',
#   'to',
#   'self',
#   'learn',
#   'photoshop',
#   'but',
#   'it',
#   'not',
#   'going',
#   'so',
#   'well',
#   '!'],
#  ['ever',
#   'seen',
#   'the',
#   'tv',
#   'show',
#   'dead',
#   'like',
#   'me',
#   'died',
#   'and',
#   'became',
#   'grim',
#   'reaper',
#   '.',
#   'taking',
#   'people',
#   'souls',
#   'after',
#   'accidents'],
#  ['sorry',
#   'thinking',
#   'about',
#   'you',
#   'and',
#   'hope',
#   'the',
#   'week',
#   'gets',
#   'better',
#   '!'],
#  ['steam',
#   'punlk',
#   'fashion',
#   'show',
#   'at',
#   'anime',
#   'north',
#   'and',
#   'for',
#   'the',
#   'first',
#   'year',
#   'since',
#   'torcon',
#   'we',
#   'aren',
#   'back',
#   'til',
#   '&',
#   'amp',
#   ';',
#   'missed',
#   'it'],
#  ['my',
#   'throat',
#   'hurts',
#   'gon',
#   'na',
#   'go',
#   'read',
#   'and',
#   'go',
#   'to',
#   'bed',
#   '.',
#   'text',
#   'mee',
#   '!'],
#  ['am', 'dying', 'to', 'hangout', 'on', 'friday', 'afternoon', '.', '.', '.'],
#  ['eh', '.', '.', 'it', 'cold'],
#  ['mannnn',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'got',
#   'an',
#   'iphone',
#   '!',
#   '!',
#   '!',
#   'im',
#   'jealous',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['fjdskal', 'im', 'really', 'frustrated', '.'],
#  ['aww', ',', 'you', 'should', "'ve", 'youtubed', 'it', '.'],
#  ['wondering',
#   'how',
#   'come',
#   'mcdonalds',
#   'take',
#   'so',
#   'long',
#   'to',
#   'deliver',
#   'my',
#   'food',
#   '.'],
#  ['ya',
#   ',',
#   'the',
#   'weather',
#   'has',
#   'been',
#   'super',
#   'weird',
#   'here',
#   '.',
#   'it',
#   'looked',
#   'like',
#   'it',
#   'was',
#   'gon',
#   'na',
#   'rain',
#   'today',
#   'but',
#   'of',
#   'course',
#   'it',
#   'didn',
#   ',',
#   'darnitt',
#   ','],
#  ['.',
#   '.',
#   '.',
#   'much',
#   'more',
#   'injustice',
#   'than',
#   'we',
#   'can',
#   'imagine',
#   'now',
#   '.',
#   'it',
#   'will',
#   'get',
#   'worse',
#   'before',
#   'it',
#   'gets',
#   'better',
#   'am',
#   'afraid',
#   '.',
#   'no',
#   'doubt',
#   'here',
#   '.',
#   'sorry'],
#  ['will',
#   'miss',
#   'nostalgia',
#   '.',
#   '.',
#   '.',
#   'everyone',
#   'please',
#   'kick',
#   'tushar'],
#  ['sooo',
#   'kind',
#   'of',
#   'sick',
#   'tired',
#   'of',
#   'the',
#   'bs',
#   'that',
#   'guys',
#   'dish',
#   'out',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['class',
#   'color',
#   'day',
#   'tomorrow',
#   '!',
#   'last',
#   'time',
#   'have',
#   'lot',
#   'to',
#   'remember',
#   'for',
#   'tomorrow',
#   'but',
#   'bet',
#   "'ll",
#   'forget-'],
#  ['idk',
#   'lol',
#   'my',
#   'head',
#   'hurts',
#   '.',
#   'rly',
#   'bad',
#   '.',
#   '&',
#   'amp',
#   ';',
#   'so',
#   'does',
#   'my',
#   'stomach',
#   '.',
#   '.',
#   '.',
#   'hmm',
#   '.',
#   '.',
#   '.',
#   'personally',
#   'think',
#   'its',
#   'from',
#   'all',
#   'the',
#   'ive',
#   'had',
#   'deal',
#   'wit'],
#  ['but', 'they', 'are', 'expensive', '.'],
#  ['wtf',
#   'facebook',
#   'just',
#   'cleared',
#   'out',
#   'my',
#   'whole',
#   'survey',
#   'and',
#   'was',
#   'on',
#   'the',
#   'last',
#   ',',
#   'this',
#   'night',
#   'gets',
#   'better',
#   'and',
#   'better',
#   'what',
#   'else',
#   'is',
#   'next',
#   '?'],
#  ['says',
#   'good',
#   '(',
#   'or',
#   'should',
#   'say',
#   'bad',
#   '?',
#   ')',
#   'afternoon',
#   '!'],
#  ['says', "'ve", 'got', 'number', '10~', 'getting', 'low~~'],
#  ['misses', 'his', 'twitastic', 'fwiends'],
#  ['take',
#   'my',
#   'advice',
#   'lookin',
#   'through',
#   'the',
#   'phone',
#   'cost',
#   'me',
#   'my',
#   'relationship'],
#  ['was', 'playing', 'street', 'fighter', 'iv', 'and', 'seth', 'raped', 'me'],
#  ['its',
#   'weird',
#   'being',
#   'at',
#   'the',
#   'guy',
#   'house',
#   'without',
#   'them',
#   'here',
#   'don',
#   'like',
#   'it'],
#  ['fuck',
#   'wasting',
#   'deodorant',
#   'aint',
#   'goin',
#   'no',
#   'where',
#   'aint',
#   'havin',
#   'company',
#   'let',
#   'me',
#   'funk',
#   'it',
#   'to',
#   'ya',
#   '!'],
#  ['wish', 'knew', '!', 'the', 'curse', 'of', 'tumblr', '.'],
#  ['what',
#   'beautiful',
#   'day',
#   '-',
#   'shame',
#   "'ve",
#   'got',
#   'to',
#   'spend',
#   'it',
#   'in',
#   'an',
#   'office'],
#  ['came',
#   'with',
#   ':',
#   '&',
#   'quot',
#   ';',
#   'any',
#   'recommended',
#   'hairdresser',
#   'full',
#   'and',
#   'they',
#   'suggested',
#   'me',
#   'to',
#   'others',
#   '&',
#   'quot',
#   ';',
#   'his',
#   'ego',
#   'talked',
#   'and',
#   'in',
#   'line'],
#  ['business', 'exam', 'tomorrow'],
#  ['oh', 'know', 'how', 'budgeting', 'is', '.'],
#  ['just',
#   'finished',
#   'watching',
#   'the',
#   'series',
#   'return',
#   'of',
#   'the',
#   'chasers',
#   'war',
#   'on',
#   'everything',
#   '-',
#   'really',
#   'quite',
#   'crap',
#   'compared',
#   'to',
#   'how',
#   'it',
#   'used',
#   'to',
#   'be'],
#  ['wow',
#   'just',
#   'realized',
#   'haven',
#   'checked',
#   'twitter',
#   'since',
#   '9am',
#   'when',
#   'saw',
#   'my',
#   'to-do',
#   'list',
#   '.',
#   'good',
#   'news-',
#   'got',
#   'lot',
#   'done',
#   '.',
#   'bad',
#   'news-don',
#   'know',
#   'where',
#   'day',
#   'went'],
#  ['-',
#   'miss',
#   'my',
#   'bestfriend',
#   ':',
#   "'",
#   '(',
#   'now',
#   'she',
#   'left',
#   'school'],
#  ['ouch', '!', 'my', 'earphones', 'just', 'shocked', 'me'],
#  ['trying', 'to', 'sleep', '!', '!', '!', 'it', 'not', 'working'],
#  ['tummy', 'hurts'],
#  ['back',
#   'from',
#   'grimsby',
#   'it',
#   'sucks',
#   'bein',
#   'back',
#   'but',
#   'was',
#   'amazin',
#   'wknd',
#   'anyway',
#   '!',
#   '!'],
#  ['farewelling', 'an', 'employee', 'tonight', '.', '.', '.'],
#  ['haha',
#   ',',
#   'its',
#   'under',
#   '18',
#   ':',
#   '@',
#   'so',
#   'ive',
#   'got',
#   'no',
#   'one',
#   'to',
#   'go',
#   'with',
#   'curse',
#   'none',
#   'of',
#   'my',
#   'friends',
#   'liking',
#   'tai',
#   'lol'],
#  ['gorgeous', 'weather', ',', 'but', 'no', 'bike'],
#  ['morning',
#   'all',
#   '.',
#   'the',
#   'water',
#   'heating',
#   'packed',
#   'up',
#   ',',
#   'so',
#   'can',
#   'have',
#   'bath',
#   'really',
#   'want',
#   'bath',
#   '!'],
#  ['girls', 'are', 'confusing', '.'],
#  ['@',
#   'lyrically_me',
#   'why',
#   'would',
#   'you',
#   'do',
#   'that',
#   'to',
#   'me',
#   '?',
#   '!'],
#  ['see',
#   'shouldn',
#   'be',
#   'comin',
#   'the',
#   'city',
#   'should',
#   'be',
#   'comin',
#   'me'],
#  ['blackout', 'in', 'the', 'city', 'is', 'never', 'good'],
#  ['aww', 'maybe', 'traumatized', 'her', '.'],
#  ['.',
#   'flights',
#   'already',
#   'booked',
#   ',',
#   'plus',
#   'its',
#   'ggd2',
#   '1st',
#   'birthday',
#   '.',
#   'can',
#   'miss',
#   'that',
#   '!',
#   'especially',
#   'as',
#   'we',
#   'missed',
#   'ggd1'],
#  ['where',
#   'live',
#   ',',
#   'all',
#   'the',
#   'small',
#   'markets',
#   'deliver',
#   'their',
#   'day-old',
#   'bread',
#   'to',
#   'the',
#   'food',
#   'bank',
#   ',',
#   'but',
#   'times',
#   'are',
#   'really',
#   'tough',
#   ',',
#   'even',
#   'for',
#   'me'],
#  ['have',
#   'drunk',
#   'hickups',
#   'had',
#   'pretty',
#   'laid',
#   'back',
#   ',',
#   'great',
#   'night',
#   '.',
#   'but',
#   'still',
#   'can',
#   'help',
#   'but',
#   'be',
#   'mad',
#   'about',
#   'the',
#   'situation',
#   'put',
#   'myself',
#   'in'],
#  ['why',
#   'do',
#   'think',
#   'have',
#   'to',
#   'take',
#   'medicine',
#   'cuz',
#   'was',
#   'laughing',
#   'to',
#   'hard',
#   '?',
#   '.',
#   'my',
#   'head',
#   'should',
#   'not',
#   'be',
#   'in',
#   'this',
#   'much',
#   'pain',
#   'thought',
#   'laughter',
#   'was',
#   'gud'],
#  ['ugh', '.', 'too', 'much', 'happened', 'today', 'really', 'need', 'hug'],
#  ['boring', 'wan', 'na', 'go', 'for', 'taekwando'],
#  ['watching',
#   'leno',
#   'for',
#   'the',
#   'second',
#   'to',
#   'last',
#   'time',
#   'on',
#   'the',
#   'tonight',
#   'show'],
#  ['ur', 'pic', 'is', 'gone'],
#  ['my', 'tongue', 'still', 'hurts', 'need', 'to', 'sleep', '!', '!', '!'],
#  ['how', 'do', 'you', 'twitter', '?'],
#  ['chris',
#   'and',
#   'are',
#   'staying',
#   'in',
#   'glasgow',
#   'instead',
#   'cause',
#   'there',
#   'is',
#   'absolutely',
#   'no',
#   'accomodation',
#   'in',
#   'edinburgh',
#   'due',
#   'to',
#   'the',
#   'marathon'],
#  ['can',
#   'wait',
#   'till',
#   'it',
#   'sunday',
#   'new',
#   'episode',
#   'of',
#   'supernatural',
#   'but',
#   'then',
#   'there',
#   'are',
#   'only',
#   'episodes',
#   'left',
#   'now'],
#  ['awww',
#   'ok',
#   'lol',
#   'hopefully',
#   'by',
#   'than',
#   'im',
#   'still',
#   'here',
#   'and',
#   'not',
#   'back',
#   'over',
#   'in',
#   'the',
#   'states'],
#  ['sad', 'tweets', 'are', 'sad'],
#  ['needs',
#   'little',
#   'lie',
#   'down',
#   '.',
#   'not',
#   'feeling',
#   'great',
#   'today',
#   '.',
#   'boo'],
#  ['not',
#   'at',
#   'my',
#   'workplace',
#   '.',
#   'but',
#   'short-sleeved',
#   'shirt',
#   'is',
#   'absolutely',
#   'necessary',
#   'today',
#   '!'],
#  ['have',
#   'decided',
#   'just',
#   'can',
#   'stand',
#   'alltop',
#   'spam',
#   'any',
#   'longer',
#   '.'],
#  ['its',
#   'from',
#   'all',
#   'that',
#   'anal',
#   'sex',
#   'forgot',
#   'the',
#   'lube',
#   '.',
#   'damn',
#   'may',
#   'need',
#   'to',
#   'go',
#   'to',
#   'the',
#   '.'],
#  ['playn',
#   'madden',
#   'with',
#   'austin',
#   '.',
#   'im',
#   'going',
#   'to',
#   'miss',
#   'him',
#   '.',
#   '.'],
#  ['miss', 'rich'],
#  ['headache',
#   'of',
#   'the',
#   'century',
#   'coming',
#   'can',
#   'feel',
#   'it',
#   'fuck',
#   '.'],
#  ['disappointed',
#   'to',
#   'know',
#   'that',
#   'got',
#   'the',
#   'silver',
#   'award',
#   'want',
#   'the',
#   'gold',
#   'award',
#   'hate',
#   'being',
#   'second',
#   'best',
#   '.'],
#  ['please',
#   'make',
#   'the',
#   'livechat',
#   'on',
#   'saturday',
#   'cus',
#   'have',
#   'to',
#   'go',
#   'to',
#   'school',
#   'on',
#   'weekdays',
#   'am',
#   'here',
#   ')'],
#  ['want',
#   'to',
#   'go',
#   'back',
#   'to',
#   'bed',
#   'but',
#   'have',
#   'child',
#   'to',
#   'look',
#   'after',
#   'may',
#   'sleep',
#   'all',
#   'of',
#   'sunday',
#   ',',
#   'my',
#   'enevitable',
#   'hangover',
#   'may',
#   'require',
#   'it',
#   '!'],
#  ['just',
#   'got',
#   'mad',
#   'tired',
#   'so',
#   'no',
#   'sex',
#   'sleepytime',
#   'night',
#   '!'],
#  ['this',
#   'twitter',
#   'shit',
#   'bores',
#   'me',
#   ',',
#   'now',
#   'haven',
#   'been',
#   'on',
#   'here',
#   'in',
#   'month'],
#  ['does',
#   'anyone',
#   'know',
#   'how',
#   'to',
#   'convert',
#   'est',
#   'to',
#   'aus',
#   'time',
#   '?',
#   'rofl',
#   'xd',
#   'fucking',
#   'radio',
#   'disney'],
#  ['home',
#   'from',
#   'ice',
#   'cream',
#   'tweet-up',
#   '(',
#   'my',
#   'very',
#   'first',
#   'tweet-up',
#   '!',
#   ')',
#   'no',
#   'pics',
#   'because',
#   'my',
#   'camera',
#   'battery',
#   'died',
#   'last',
#   'night',
#   'and',
#   'forgot',
#   'to',
#   'charge',
#   'it'],
#  ['ok',
#   'that',
#   'subtly',
#   'saying',
#   'no',
#   'longer',
#   'fave',
#   'temme',
#   'thing',
#   '-',
#   'did',
#   'the',
#   'firangs',
#   'steal',
#   'your',
#   'vocab',
#   '?',
#   'ur',
#   'eating',
#   'words',
#   'and',
#   'how',
#   '!'],
#  ['bye',
#   ',',
#   'scotty',
#   'gon',
#   'na',
#   'miss',
#   'you',
#   '.',
#   'ily',
#   '&',
#   'lt',
#   ';',
#   '333'],
#  ['new',
#   'comment',
#   'on',
#   'jowki',
#   'wish',
#   'had',
#   'the',
#   'time',
#   'to',
#   'blog',
#   'more',
#   'often'],
#  ['we',
#   'can',
#   'get',
#   'temporary',
#   'tattoo',
#   'would',
#   'be',
#   'totally',
#   'sad',
#   'if',
#   'he',
#   'died',
#   '.'],
#  ['gray', 'so', 'feel', 'neglected'],
#  ['oh',
#   'so',
#   'you',
#   'know',
#   'how',
#   'feel',
#   'then',
#   'damn',
#   'representative',
#   'for',
#   'bank',
#   'of',
#   'america',
#   'tried',
#   'to',
#   'make',
#   'it',
#   'sound',
#   'like',
#   'did',
#   'it',
#   '.',
#   'what',
#   '.',
#   '.',
#   '.'],
#  ['is', 'tired', 'and', 'cold', 'and', 'runny'],
#  ['dun',
#   'wan',
#   'na',
#   'travel',
#   'all',
#   'the',
#   'way',
#   'there',
#   'for',
#   'lunch',
#   'now',
#   '.',
#   'but',
#   'yeah',
#   'have',
#   'been',
#   'there',
#   '.',
#   'nice',
#   'place',
#   '.',
#   'missing',
#   'shan-punjab',
#   'though',
#   '.',
#   '.',
#   '.'],
#  ['doing',
#   'mass',
#   'cleanout',
#   'of',
#   'my',
#   'room',
#   'before',
#   'rearranging',
#   'it',
#   '.',
#   'just',
#   'sent',
#   'mother',
#   'out',
#   'to',
#   'buy',
#   'me',
#   'bin',
#   'and',
#   'bookshelf',
#   'since',
#   'mine',
#   'sucks',
#   '.',
#   'bad',
#   'mood'],
#  ['rob', 'got', 'lucky', 'that', 'game', 'he', 'beat', 'me', '209-205'],
#  ['feeling',
#   'really',
#   'sick',
#   'watching',
#   'the',
#   'fifth',
#   'element',
#   ',',
#   'and',
#   'about',
#   'to',
#   'smoke',
#   'cigg',
#   '.',
#   'ugh',
#   'hate',
#   'colds',
#   '!'],
#  ['bah', 'don', 'think', 'fb', 'fan', 'page', 'will', 'get', 'to', '7500'],
#  ['someone', 'save', 'me', 'dont', 'want', 'to', 'pack', 'anymore'],
#  ['home', 'from', 'school', 'had', 'the', 'shitest', 'day', 'today'],
#  ['the',
#   'sweety',
#   'sat',
#   'on',
#   'the',
#   'table',
#   'this',
#   'morning',
#   '.',
#   '.',
#   '.',
#   'just',
#   'woke',
#   'up',
#   '!',
#   'very',
#   'sweet',
#   '!',
#   'oh',
#   '.',
#   '.',
#   '.',
#   'btw',
#   'think',
#   "'ll",
#   'be',
#   'home',
#   'around',
#   'pm',
#   '!',
#   '!',
#   '!',
#   'xxx'],
#  ['bruise',
#   'on',
#   'knee',
#   'will',
#   'make',
#   'it',
#   'hard',
#   'to',
#   'skate',
#   'tomorrow',
#   '.'],
#  ['lol',
#   '.',
#   'when',
#   'went',
#   'to',
#   'buy',
#   'my',
#   'new',
#   'laptop',
#   'in',
#   'feb',
#   'already',
#   'knew',
#   ',',
#   'lol',
#   ',',
#   'but',
#   'looked',
#   'anyway',
#   'and',
#   'walked',
#   'away',
#   'sadfaced',
#   '.',
#   ':',
#   '/'],
#  ['fyi',
#   'no',
#   'internets',
#   'until',
#   'thurstag',
#   '!',
#   '!',
#   '!',
#   '!',
#   'after',
#   'saturday',
#   'have',
#   'feeling',
#   'will',
#   'become',
#   '800x',
#   'more',
#   'productive',
#   'during',
#   'those',
#   'days',
#   '.'],
#  ['sitting',
#   'by',
#   'myself',
#   '.',
#   'everyone',
#   'took',
#   'the',
#   'good',
#   'seats',
#   '.'],
#  ['no',
#   'free',
#   'wifi',
#   '!',
#   '?',
#   '!',
#   '?',
#   'my',
#   'vacay',
#   'is',
#   'ruined',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['ahhhhh', 'well', 'at', 'least', 'up', 'to', '!'],
#  ['maatt',
#   'havent',
#   'spoken',
#   'to',
#   'you',
#   'in',
#   'ages',
#   'dudeee',
#   'dont',
#   'forget',
#   'bout',
#   'ur',
#   'aussie',
#   'fan',
#   ';',
#   ')',
#   'lool',
#   '.',
#   'love',
#   'ya',
#   'xx'],
#  ['me', '!', 'oh', 'wait', 'wrong', 'state'],
#  ['it',
#   'fucking',
#   'cold',
#   'here',
#   'north',
#   'now',
#   '!',
#   'it',
#   'was',
#   'like',
#   '77',
#   'df',
#   'yesterday',
#   'where',
#   'was',
#   ',',
#   'here',
#   'it',
#   '37'],
#  ['are',
#   'missing',
#   'ur',
#   'frnds',
#   '?',
#   'hear',
#   'to',
#   '&',
#   'quot',
#   ';',
#   'manasellaam',
#   '&',
#   'quot',
#   ';',
#   'from',
#   'kulir100',
#   'degree',
#   'movie',
#   '.',
#   'its',
#   'amazing',
#   '!',
#   '!',
#   '!',
#   'nanbargale',
#   '-',
#   'miss',
#   'guys',
#   '!',
#   '!',
#   '!'],
#  ['trying',
#   'to',
#   'sleep',
#   'without',
#   'any',
#   'pills',
#   '.',
#   '.',
#   '.',
#   'not',
#   'working',
#   '.',
#   '3am',
#   'and',
#   'wide',
#   'awake',
#   '.',
#   'but',
#   'now',
#   'it',
#   'too',
#   'late',
#   'to',
#   'take',
#   'them',
#   'because',
#   "'ll",
#   'sleep',
#   'til',
#   '3pm'],
#  ['phone',
#   'will',
#   'die',
#   'soon',
#   '.',
#   'what',
#   'to',
#   'do',
#   'now',
#   '?',
#   'oh',
#   'no',
#   '!'],
#  ['sorry', 'was', 'that', 'mean'],
#  ['forgot', 'my', 'power', 'cable', 'at', 'home', 'today'],
#  ['dogs',
#   'eyes',
#   'seem',
#   'bad',
#   '.',
#   'just',
#   'forked',
#   'out',
#   'on',
#   'new',
#   'washing',
#   'machine',
#   'so',
#   'why',
#   'not',
#   'vets',
#   'bill',
#   'to',
#   'top',
#   'it',
#   'off',
#   'eh',
#   '?',
#   '!',
#   '?',
#   '!'],
#  ['can',
#   'sleep',
#   'can',
#   'find',
#   'my',
#   'grandmother',
#   'quilt',
#   'or',
#   'locket',
#   'sick',
#   'at',
#   'myself',
#   'cause',
#   'may',
#   'have',
#   'lost',
#   'them',
#   'somehow',
#   '.',
#   'or',
#   'they',
#   'were',
#   'stolen'],
#  ['thought', 'was', 'going', 'to', 'see', 'pic', 'of', 'your', 'clean', 'car'],
#  ['want',
#   'to',
#   '!',
#   'but',
#   'im',
#   'not',
#   'over',
#   '18',
#   'and',
#   '&',
#   'amp',
#   'says',
#   'over',
#   '18',
#   'only',
#   'wan',
#   'na',
#   'make',
#   'an',
#   'exception',
#   'for',
#   'me',
#   ';',
#   ')'],
#  ['no',
#   ',',
#   'but',
#   'it',
#   'does',
#   'amazing',
#   'things',
#   'with',
#   'keeping',
#   'all',
#   'your',
#   'online',
#   'conversations',
#   'in',
#   'one',
#   'place',
#   '.',
#   '.',
#   '.',
#   'unfortunately',
#   'that',
#   'place',
#   'is',
#   'google'],
#  ['sorry', ',', 'is', 'only', 'in', 'spanish', 'for', 'the', 'moment'],
#  ['yayyyyyyyyyyy',
#   '!',
#   '!',
#   '!',
#   '!',
#   '!',
#   'but',
#   'thats',
#   'sp',
#   'far',
#   'away',
#   '!'],
#  ['must',
#   'clear',
#   'out',
#   'my',
#   'dvr',
#   '.',
#   '.',
#   '.',
#   'getting',
#   'rid',
#   'of',
#   'it',
#   'tomorrw',
#   '.'],
#  ['bummed', 'that', '!', 'broke', 'up'],
#  ['signed',
#   'up',
#   'for',
#   'an',
#   'account',
#   'on',
#   'political',
#   'website',
#   'so',
#   'could',
#   'post',
#   'comment',
#   'but',
#   'it',
#   'isn',
#   'working',
#   '.'],
#  ['how', 'come', 'can', 'never', 'sleep', 'past', '?', '?', 'not', 'good'],
#  ...]

# %% [markdown]
# #### Train fastText

# %%
from gensim.models.fasttext import FastText


model = FastText(sentences=text_df.to_list(), vector_size=128)

model.train(corpus_iterable=text_df.to_list(), epochs=model.epochs, total_examples=model.corpus_count, total_words=model.corpus_total_words)
# Out:
# (12336665, 14729215)

# %%
from pprint import pprint

ft = model.wv

pprint(ft.similarity("sad", "happy"))
pprint(ft.most_similar("happy"))
# Out:
# 0.3841868
# [('happy-day', 0.8413798213005066),
#  ('sappy', 0.7685059905052185),
#  ('happily', 0.737735390663147),
#  ('happier', 0.6955354809761047),
#  ('happiest', 0.6740206480026245),
#  ('lappy', 0.6732267141342163),
#  ('snappy', 0.6727899312973022),
#  ('nappy', 0.671665608882904),
#  ('unhappy', 0.6370724439620972),
#  ('peppy', 0.5859425067901611)]

# %%
print(f"{'fires' in ft.key_to_index}")

pprint(ft.most_similar("fires"))
# Out:
# True
# [('wires', 0.8612368702888489),
#  ('fireflies', 0.8237053751945496),
#  ('es', 0.822934627532959),
#  ('ropes', 0.821685791015625),
#  ('pores', 0.8034000396728516),
#  ('claires', 0.7939077615737915),
#  ('vampires', 0.788116991519928),
#  ('fixes', 0.7749882936477661),
#  ('ales', 0.7745190858840942),
#  ('poles', 0.7737336158752441)]
